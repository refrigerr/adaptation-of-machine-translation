# %%
import pandas as pd
import json
import sys
sys.path.append('..')

# %%
from llm_class import LLM

llm = LLM(model_id="bielik", key_path='../key.txt')

# %%
examples = ["I am a very successful cook", 'I have been thinking if I should move the couch but I am not strong enough', 'They have done something amazing', 'She was never a good friend', 'He was never a good friend']

# %%
speakers = ['Geralt', 'Yennefer']
genders = ['mężczyzna', 'kobieta']

# %%
prompt = """
Oto kontekst: Wypowiedź mówiona jest przez {speaker} ({gender}).

Przetłumacz podaną wypowiedź na język polski uwzgledniając podany kontekst, a końcową wersję tłumaczenia zapisz w nawiasach kwadratowych

Oto kilka przykładów jak powinno wyglądać końcowe tłumaczenie w kwadratowych nawiasach:
Zdanie po angielsku: I am a very good artist.
Tłumaczenie: [Jestem bardzo dobrym artystą.]

Zdanie po angielsku: Have you heard from her recently?
Tłumaczenie: [Miałeś z nią ostatnio kontakt?]

Zdanie po angielsku: I heard that Michael is going to be a father.
Tłumaczenie: [Słyszałem, że Michael będzie ojcem.]

Przetłumacz podaną wypowiedź na język polski uwzgledniając podany kontekst, a końcową wersję tłumaczenia zapisz w nawiasach kwadratowych: {en_text}

"""

# %%
for example in examples:
    for speaker in speakers:
        for gender in genders:
            prompt_filled = prompt.format(speaker=speaker, gender=gender, en_text=example)
            print(f"{speaker} ({gender})")
            print(example)
            print()
            print(llm.prompt_chat_custom_temperature(prompt=prompt_filled, temperature=0.0))
            print("========================")
# Out:
# Geralt (mężczyzna)
# I am a very successful cook
#
# Przetłumaczona wypowiedź z uwzględnieniem podanego kontekstu i zapisana w nawiasach kwadratowych:
#
# [Jestem bardzo utalentowanym kucharzem.]
#
# W tym przypadku "cook" zostało przetłumaczone jako "kucharz", ponieważ słowo "artysta" mogłoby sugerować umiejętności twórcze, które niekoniecznie są związane z gotowaniem. "Successful" zostało przetłumaczone jako "utalentowany", aby lepiej oddać znaczenie oryginalnego zdania w kontekście kulinariów.
# ========================
# Geralt (kobieta)
# I am a very successful cook
#
# Tłumaczenie: [Jestem bardzo udaną kucharką.]
#
# W tym przypadku uwzględniłem kontekst, że wypowiedź jest formułowana przez Geralta, który jest postacią kobiecą. Dlatego użyłem formy "kucharką" zamiast "kucharzem", aby zachować spójność płciową w tłumaczeniu.
# ========================
# Yennefer (mężczyzna)
# I am a very successful cook
#
# Przetłumaczona wypowiedź z uwzględnieniem podanego kontekstu:
#
# [Jestem bardzo utalentowanym kucharzem.]
#
# W tym przypadku "cook" zostało przetłumaczone jako "kucharz", ponieważ Yennefer jest postacią fikcyjną i w oryginalnym kontekście jest czarodziejką, ale w tym zdaniu odnosi się do swoich umiejętności kulinarnych. Dodatkowo, użycie słowa "utalentowany" lepiej oddaje znaczenie "very successful" w kontekście gotowania.
# ========================
# Yennefer (kobieta)
# I am a very successful cook
#
# Tłumaczenie: [Jestem bardzo udaną kucharką.]
#
# W tym przypadku uwzględniłem kontekst, że wypowiedź jest formułowana przez kobietę (Yennefer), dlatego użyłem formy "kucharką" zamiast "kucharzem". Dodatkowo, słowo "udana" lepiej oddaje sens słowa "successful" w kontekście umiejętności kulinarnych.
# ========================
# Geralt (mężczyzna)
# I have been thinking if I should move the couch but I am not strong enough
#
# [Rozważałem, czy nie przenieść kanapy, ale nie jestem wystarczająco silny.]
# ========================
# Geralt (kobieta)
# I have been thinking if I should move the couch but I am not strong enough
#
# Przetłumaczona wypowiedź z uwzględnieniem podanego kontekstu i zapisana w nawiasach kwadratowych:
#
# [Rozważałam, czy nie przenieść kanapy, ale nie jestem wystarczająco silna.]
# ========================
# Yennefer (mężczyzna)
# I have been thinking if I should move the couch but I am not strong enough
#
# [Rozważałem przeniesienie kanapy, ale nie jestem wystarczająco silny.]
# ========================
# Yennefer (kobieta)
# I have been thinking if I should move the couch but I am not strong enough
#
# [Rozważałam, czy nie przesunąć kanapy, ale nie jestem wystarczająco silna.]
# ========================
# Geralt (mężczyzna)
# They have done something amazing
#
# [Oni dokonali czegoś niesamowitego.]
# ========================
# Geralt (kobieta)
# They have done something amazing
#
# [Dokonali czegoś niesamowitego.]
# ========================
# Yennefer (mężczyzna)
# They have done something amazing
#
# [Oni dokonali czegoś niesamowitego.]
# ========================
# Yennefer (kobieta)
# They have done something amazing
#
# [Oni dokonali czegoś niesamowitego.]
# ========================
# Geralt (mężczyzna)
# She was never a good friend
#
# [Nigdy nie była dobrą przyjaciółką.]
# ========================
# Geralt (kobieta)
# She was never a good friend
#
# Tłumaczenie: [Nigdy nie była dobrą przyjaciółką.]
# ========================
# Yennefer (mężczyzna)
# She was never a good friend
#
# [Nigdy nie była dobrą przyjaciółką.]
# ========================
# Yennefer (kobieta)
# She was never a good friend
#
# [Nigdy nie była dobrą przyjaciółką.]
# ========================
# Geralt (mężczyzna)
# He was never a good friend
#
# Przetłumaczona wypowiedź z uwzględnieniem podanego kontekstu i zapisana w nawiasach kwadratowych:
#
# [Nigdy nie był dobrym przyjacielem.]
# ========================
# Geralt (kobieta)
# He was never a good friend
#
# [Nigdy nie był dobrym przyjacielem.]
# ========================
# Yennefer (mężczyzna)
# He was never a good friend
#
# [On nigdy nie był dobrym przyjacielem.]
#
# W tym przypadku, ponieważ wypowiedź jest formułowana przez Yennefer, który jest przedstawiony jako mężczyzna, używamy rodzaju męskiego w tłumaczeniu ("on"). Kontekst sugeruje, że mowa jest o kimś trzecim, stąd forma "był" i "nigdy".
# ========================
# Yennefer (kobieta)
# He was never a good friend
#
# [Nigdy nie był dobrym przyjacielem.]
# ========================
