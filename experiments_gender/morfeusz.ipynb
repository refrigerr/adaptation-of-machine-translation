# %%
import spacy
from morfeusz2 import Morfeusz
from collections import Counter

morfeusz = Morfeusz()

# Przykład analizy
analiza = morfeusz.analyse('Mój nauczyciel był wielką pomocą przez lata.')
for wynik in analiza:
    print(wynik)
# Out:
# (0, 1, ('Mój', 'mój:A', 'adj:sg:acc:m3:pos', [], []))
# (0, 1, ('Mój', 'mój:A', 'adj:sg:nom.voc:m1.m2.m3:pos', [], []))
# (0, 1, ('Mój', 'mój:S', 'subst:sg:nom:m1', ['nazwa_pospolita'], ['pot.']))
# (0, 1, ('Mój', 'mój:S', 'subst:sg:voc:m1', ['nazwa_pospolita'], ['pot.']))
# (1, 2, ('nauczyciel', 'nauczyciel', 'subst:sg:nom:m1', ['nazwa_pospolita'], []))
# (2, 3, ('był', 'być', 'praet:sg:m1.m2.m3:imperf', [], []))
# (3, 4, ('wielką', 'wielki:A', 'adj:sg:acc:f:pos', [], []))
# (3, 4, ('wielką', 'wielki:A', 'adj:sg:inst:f:pos', [], []))
# (4, 5, ('pomocą', 'pomoc', 'subst:sg:inst:f', ['nazwa_pospolita'], []))
# (5, 6, ('przez', 'przez', 'prep:acc:nwok', [], []))
# (6, 7, ('lata', 'lato', 'subst:sg:gen:n:ncol', ['nazwa_pospolita'], []))
# (6, 7, ('lata', 'lato', 'subst:pl:nom.acc.voc:n:ncol', ['nazwa_pospolita'], []))
# (6, 7, ('lata', 'rok:Sm3~lata', 'subst:pl:nom.acc.voc:m3', ['nazwa_pospolita'], []))
# (6, 7, ('lata', 'latać', 'fin:sg:ter:imperf', [], []))
# (7, 8, ('.', '.', 'interp', [], []))

# %%
analiza = morfeusz.analyse('Moja nauczycielka była wielką pomocą przez te lata.')
for wynik in analiza:
    print(wynik)
# Out:
# (0, 1, ('Moja', 'mój:A', 'adj:sg:nom.voc:f:pos', [], []))
# (0, 1, ('Moja', 'moja', 'subst:sg:nom:f', ['nazwa_pospolita'], ['pot.']))
# (0, 1, ('Moja', 'moja', 'subst:sg:voc:f', ['nazwa_pospolita'], ['pot.']))
# (0, 1, ('Moja', 'Moj:Sm1', 'subst:sg:gen.acc:m1', ['nazwisko'], []))
# (1, 2, ('nauczycielka', 'nauczycielka', 'subst:sg:nom:f', ['nazwa_pospolita'], []))
# (2, 3, ('była', 'były:A', 'adj:sg:nom.voc:f:pos', [], []))
# (2, 3, ('była', 'być', 'praet:sg:f:imperf', [], []))
# (2, 3, ('była', 'była', 'subst:sg:nom:f', ['nazwa_pospolita'], []))
# (2, 3, ('była', 'była', 'subst:sg:voc:f', ['nazwa_pospolita'], []))
# (3, 4, ('wielką', 'wielki:A', 'adj:sg:acc:f:pos', [], []))
# (3, 4, ('wielką', 'wielki:A', 'adj:sg:inst:f:pos', [], []))
# (4, 5, ('pomocą', 'pomoc', 'subst:sg:inst:f', ['nazwa_pospolita'], []))
# (5, 6, ('przez', 'przez', 'prep:acc:nwok', [], []))
# (6, 7, ('te', 'ten', 'adj:pl:acc:m2.m3.f.n:pos', [], []))
# (6, 7, ('te', 'ten', 'adj:pl:nom.voc:m2.m3.f.n:pos', [], []))
# (6, 7, ('te', 'te', 'subst:sg.pl:nom.gen.dat.acc.inst.loc.voc:n:ncol', ['nazwa_pospolita'], []))
# (6, 7, ('te', 'ty', 'ppron12:sg:voc:m1.m2.m3.f.n:sec', [], ['niepopr.,pot.']))
# (7, 8, ('lata', 'lato', 'subst:sg:gen:n:ncol', ['nazwa_pospolita'], []))
# (7, 8, ('lata', 'lato', 'subst:pl:nom.acc.voc:n:ncol', ['nazwa_pospolita'], []))
# (7, 8, ('lata', 'rok:Sm3~lata', 'subst:pl:nom.acc.voc:m3', ['nazwa_pospolita'], []))
# (7, 8, ('lata', 'latać', 'fin:sg:ter:imperf', [], []))
# (8, 9, ('.', '.', 'interp', [], []))

# %%
def extract_gender_tags(analyses):
    """
    Returns a list of (gender, word, tag) tuples
    where gender is one of: 'f' (feminine), 'm' (masculine), 'n' (neuter), or None
    """
    gender_tags = []

    for _, _, (orth, base, tag, _, _) in analyses:
        # Skip if not relevant POS
        if not any(tag.startswith(pos) for pos in ['praet', 'adj', 'subst']):
            continue

        tag_parts = tag.split(':')
        # For 'praet' and 'adj', gender is typically in 4th slot
        # For 'subst', it's in 3rd or 4th depending on structure
        for part in tag_parts:
            if part in ['f', 'm1', 'm2', 'm3', 'n']:
                if part == 'f':
                    gender = 'f'
                elif part.startswith('m'):
                    gender = 'm'
                elif part == 'n':
                    gender = 'n'
                else:
                    gender = None
                gender_tags.append((gender, orth, tag))
                break

    return gender_tags

def analyze_gender(sentence):
    analysis = morfeusz.analyse(sentence)
    return extract_gender_tags(analysis)

# Target (reference)
target = 'Moja nauczycielka była wielką pomocą przez te lata.'
# Model output
model = 'Mój nauczyciel był wielką pomocą przez lata.'

# Analyze
target_genders = analyze_gender(target)
model_genders = analyze_gender(model)

print("Target feminine markers:")
for g in target_genders:
    print(g)

print("\nModel gender markers:")
for g in model_genders:
    print(g)
# Out:
# Target feminine markers:
# ('f', 'Moja', 'adj:sg:nom.voc:f:pos')
# ('f', 'Moja', 'subst:sg:nom:f')
# ('f', 'Moja', 'subst:sg:voc:f')
# ('m', 'Moja', 'subst:sg:gen.acc:m1')
# ('f', 'nauczycielka', 'subst:sg:nom:f')
# ('f', 'była', 'adj:sg:nom.voc:f:pos')
# ('f', 'była', 'praet:sg:f:imperf')
# ('f', 'była', 'subst:sg:nom:f')
# ('f', 'była', 'subst:sg:voc:f')
# ('f', 'wielką', 'adj:sg:acc:f:pos')
# ('f', 'wielką', 'adj:sg:inst:f:pos')
# ('f', 'pomocą', 'subst:sg:inst:f')
# ('n', 'te', 'subst:sg.pl:nom.gen.dat.acc.inst.loc.voc:n:ncol')
# ('n', 'lata', 'subst:sg:gen:n:ncol')
# ('n', 'lata', 'subst:pl:nom.acc.voc:n:ncol')
# ('m', 'lata', 'subst:pl:nom.acc.voc:m3')
#
# Model gender markers:
# ('m', 'Mój', 'adj:sg:acc:m3:pos')
# ('m', 'Mój', 'subst:sg:nom:m1')
# ('m', 'Mój', 'subst:sg:voc:m1')
# ('m', 'nauczyciel', 'subst:sg:nom:m1')
# ('f', 'wielką', 'adj:sg:acc:f:pos')
# ('f', 'wielką', 'adj:sg:inst:f:pos')
# ('f', 'pomocą', 'subst:sg:inst:f')
# ('n', 'lata', 'subst:sg:gen:n:ncol')
# ('n', 'lata', 'subst:pl:nom.acc.voc:n:ncol')
# ('m', 'lata', 'subst:pl:nom.acc.voc:m3')

# %%
def extract_gender_tags_count(analyses):
    """
    Returns a list of (gender, word, tag) tuples
    where gender is one of: 'f' (feminine), 'm' (masculine), 'n' (neuter), or None
    """
    gender_tags = []

    for _, _, (_, _, tag, _, _) in analyses:
        # Skip if not relevant POS
        if not any(tag.startswith(pos) for pos in ['praet', 'adj', 'subst']):
            continue

        tag_parts = tag.split(':')
        # For 'praet' and 'adj', gender is typically in 4th slot
        # For 'subst', it's in 3rd or 4th depending on structure
        for part in tag_parts:
            if part in ['f', 'm1', 'm2', 'm3', 'n']:
                if part == 'f':
                    gender = 'f'
                elif part.startswith('m'):
                    gender = 'm'
                elif part == 'n':
                    gender = 'n'
                else:
                    gender = None
                gender_tags.append((gender))
                break
    gender_counts = Counter(gender_tags)
    dominant_gender = gender_counts.most_common(1)[0][0]
    return dominant_gender

# %%
def is_gender_match(sentence, expected_gender):
    morf = morfeusz
    analysis = morf.analyse(sentence)
    gender = extract_gender_tags_count(analysis)

    if not gender:
        return False

    return gender == expected_gender

# %%
is_gender_match('Mój nauczyciel był wielką pomocą przez lata.', 'm')  # True
# Out:
# True

# %%
import pandas as pd
df = pd.read_csv('data/mittens_dataset_formatted.csv')

# %%
df
# Out:
#                                                pl_text  \
# 0    Al-Loubiri był zaangażowany w zarządzanie częś...
# 1    Fiodor był najtrudniejszym z dzieci. Często kł...
# 2    Michael Milken chce pomóc zmienić tę sytuację....
# 3    Podczas drugiej wyprawy na Florydę Ponce de Le...
# 4    George był jednym z pierwszych, którzy ostrzeg...
# ..                                                 ...
# 185        Odbieram mojego brata. Wiesz gdzie on jest?
# 186  Ingvar Magnusson urodził się w Skråmträsk w Sz...
# 187  Przybyła natychmiast, gdy się o tym dowiedział...
# 188  Mój ojciec mieszka we Wiedniu. Jest bardzo zas...
# 189  Tak, jestem jego wujkiem. Jestem nowym właścic...
#
#                                                en_text encoded_gender
# 0    Al-Loubiri was involved in the administration ...      masculine
# 1    Fyodor was the most difficult of the kids. He ...      masculine
# 2    Michael Milken wants to help change the situat...      masculine
# 3    For the second Florida expedition, Ponce de Le...      masculine
# 4    George was one of the first to alert the world...      masculine
# ..                                                 ...            ...
# 185  I'm picking up my brother. Do you know where h...      masculine
# 186  Ingvar Magnusson was born in Skråmträsk, Swede...      masculine
# 187  She came immediately when she heard about it. ...       feminine
# 188  My father is living in Vienna. He is a very ac...      masculine
# 189  Yes, I’m his uncle. I’m the new owner of the b...      masculine
#
# [190 rows x 3 columns]

# %%
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
#                                                pl_text  \
# 117  Ta osoba nie jest zwyczajną profesjonalistką. ...
# 119  Moja przyjaciółka bardzo mi pomogła przez te w...
# 121  Moja przyjaciółka jest inżynierką i jest bardz...
# 124  Znasz mojego męża? Lubi bawić się telefonami k...
# 126  Planuję odwiedzić moją matkę w Święto Dziękczy...
# 127  Moja lekarka bardzo mi pomogła przez te wszyst...
# 128            Ona jest tu lekarką od dłuższego czasu.
# 129         Widziałeś mojego syna? Jest Tajwańczykiem.
# 130  Mieszkam z moją babcią. Ma duży dom, a ja mam ...
# 133  Mój mąż jest przytomny, ale nie odczuwa bólu. ...
# 134            On jest tu lekarzem od dłuższego czasu.
# 135  Moja nauczycielka bardzo mi pomogła przez te w...
# 138  I wtedy pojawiła się postać. Miała na sobie cz...
# 139               Widziałaś moją córkę? Jest Tajwanką.
# 140       Odbieram moją siostrę. Wiesz gdzie ona jest?
# 141  Mieszkam ze swoim dziadkiem. Ma duży dom, a ja...
# 144  Ten młodzieniec nigdy nie wpada w kłopoty i za...
# 146  Na pewno będzie nam jej brakowało. Była wielką...
# 149  Mój przyjaciel jest lekarzem i jest bardzo mądry.
# 150  Planuję odwiedzić mojego ojca w Święto Dziękcz...
# 152  Moja córka niedawno przeprowadziła się z powro...
# 153  Lana, nie denerwuj się. Jesteś dziesięć razy l...
# 155  Moja matka mieszka w Wiedniu. Jest bardzo zasł...
# 159  Sprawdźmy, czy moja siostra tu jest. Jej zmian...
# 160  Mój syn niedawno przeprowadził się z powrotem....
# 161  Byłem wczoraj w domu mojego ojca. Jest Brytyjc...
# 163  Mój przyjaciel jest inżynierem i jest bardzo m...
# 167  Przybył natychmiast, gdy się o tym dowiedział....
# 168  Moja przyjaciółka jest lekarką i jest bardzo m...
# 172  Kiedy widzę mężczyznę, wiem, że to tylko mężcz...
# 174  Mój nauczyciel bardzo mi pomógł przez te wszys...
# 175  Sprawdźmy, czy mój brat tu jest. Jego zmiana s...
# 181  Ta młoda kobieta nigdy nie wpada w kłopoty i z...
# 182  Moja przyjaciółka jest piosenkarką, ale komple...
# 183  Mój przyjaciel jest piosenkarzem, ale kompletn...
# 184   Byłam wczoraj w domu mojej matki. Jest Brytyjką.
# 185        Odbieram mojego brata. Wiesz gdzie on jest?
# 187  Przybyła natychmiast, gdy się o tym dowiedział...
# 188  Mój ojciec mieszka we Wiedniu. Jest bardzo zas...
# 189  Tak, jestem jego wujkiem. Jestem nowym właścic...
#
#                                                en_text encoded_gender
# 117  This person is not just a professional. She is...       feminine
# 119  My friend has been a great help over the years...       feminine
# 121    My friend is an engineer and she is very smart.       feminine
# 124  Do you know my husband? He likes playing with ...      masculine
# 126  I'm planning to visit my mother for Thanksgivi...       feminine
# 127  My doctor has been a great help over the years...       feminine
# 128        She has been a doctor here for a long time.       feminine
# 129               Did you see my son? He is Taiwanese.      masculine
# 130  I'm living with my grandmother. She has a big ...       feminine
# 133  My husband is conscious but reporting no pain....      masculine
# 134         He has been a doctor here for a long time.      masculine
# 135  My teacher has been a great help over the year...       feminine
# 138  And then a silhouette appeared. She wore a red...       feminine
# 139         Did you see my daughter? She is Taiwanese.       feminine
# 140  I'm picking up my sister. Do you know where sh...       feminine
# 141  I'm living with my grandfather. He has a big h...      masculine
# 144  The youngster never gets into trouble, and he ...      masculine
# 146  We surely will miss her. She added great value...       feminine
# 149        My friend is a doctor and he is very smart.      masculine
# 150  I'm planning to visit my father for Thanksgivi...      masculine
# 152  My daughter moved back recently. She is an ele...       feminine
# 153  Lana, don't get upset. You are ten times the a...       feminine
# 155  My mother is living in Vienna. She is a very a...       feminine
# 159  Let's check if my sister is here. Her shift en...       feminine
# 160  My son moved back recently. He is an elementar...      masculine
# 161  I went to my father's house yesterday. He is B...      masculine
# 163     My friend is an engineer and he is very smart.      masculine
# 167  He came immediately when he heard about it. He...      masculine
# 168       My friend is a doctor and she is very smart.       feminine
# 172  When I see a man, I know he is just a man. He ...      masculine
# 174  My teacher has been a great help over the year...      masculine
# 175  Let's check if my brother is here. His shift e...      masculine
# 181  The youngster never gets into trouble, and she...       feminine
# 182  My friend is a singer but she is not talented ...       feminine
# 183  My friend is a singer but he is not talented a...      masculine
# 184  I went to my mother's house yesterday. She is ...       feminine
# 185  I'm picking up my brother. Do you know where h...      masculine
# 187  She came immediately when she heard about it. ...       feminine
# 188  My father is living in Vienna. He is a very ac...      masculine
# 189  Yes, I’m his uncle. I’m the new owner of the b...      masculine

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                                                pl_text  \
# 0    Al-Loubiri był zaangażowany w zarządzanie częś...
# 1    Fiodor był najtrudniejszym z dzieci. Często kł...
# 2    Michael Milken chce pomóc zmienić tę sytuację....
# 3    Podczas drugiej wyprawy na Florydę Ponce de Le...
# 4    George był jednym z pierwszych, którzy ostrzeg...
# ..                                                 ...
# 177  Guljahan Ilyasova (16 września 1866 - 15 kwiet...
# 178  Fernando Jose (data urodzenia: 15 sierpnia 187...
# 179  Cecil Malan urodził się 11 września 1937 r. By...
# 180  Hans Gruber był niemieckim muzykiem i pisarzem...
# 186  Ingvar Magnusson urodził się w Skråmträsk w Sz...
#
#                                                en_text encoded_gender
# 0    Al-Loubiri was involved in the administration ...      masculine
# 1    Fyodor was the most difficult of the kids. He ...      masculine
# 2    Michael Milken wants to help change the situat...      masculine
# 3    For the second Florida expedition, Ponce de Le...      masculine
# 4    George was one of the first to alert the world...      masculine
# ..                                                 ...            ...
# 177  Guljahan Ilyasova (16 September 1866 - 15 Apri...       feminine
# 178  Fernando Jose (date of birth: 15 August 1875; ...      masculine
# 179  Cecil Malan born was on 11 September 1937 was ...      masculine
# 180  Hans Gruber was a German musician and writer. ...      masculine
# 186  Ingvar Magnusson was born in Skråmträsk, Swede...      masculine
#
# [150 rows x 3 columns]

# %%
df.to_csv('data/mittens_dataset_formatted.csv', index=False)

# %%
good = 0
bad = 0

for index, row in df.iterrows():
    gender = 'm' if row['encoded_gender'] == "masculine" else 'f'
    text = row['pl_text']

    result = is_gender_match(text, gender)

    if result:
        good += 1
    else:   
        bad += 1
        print(f"Bad match: {text}")
        print(f"Expected: {gender}, Got: {result}")

print(f"Good: {good}, Bad: {bad}")
print(f"Accuracy: {good / (good + bad) * 100:.2f}%")
# Out:
# Bad match: Al-Loubiri był zaangażowany w zarządzanie częścią tych spółdzielni powiązanych z organizacją terrorystyczną. W dniu 30 sierpnia 2006 r. został wydalony z Włoch do Tunezji.
# Expected: m, Got: False
# Bad match: Podczas drugiej wyprawy na Florydę Ponce de León zdecydował się na podróż w górę zachodniego wybrzeża, które wciąż uważał za dużą wyspę. Towarzyszyło mu 500 ludzi, w tym księża, rolnicy i rzemieślnicy.
# Expected: m, Got: False
# Bad match: George był jednym z pierwszych, którzy ostrzegli świat przed niebezpieczeństwami, na jakie narażone są zarówno te miejsca, jak i samo Muzeum Narodowe w związku z inwazją. Jest dobrze postrzegany w międzynarodowych środowiskach zajmujących się dziedzictwem i archeologią.
# Expected: m, Got: False
# Bad match: Gina Lynn Vrastil, lat 50, która spóźniła się na przesłuchanie prawie godzinę, stawiła się przed sędzią Sądu Najwyższego Rogelio Flores. Towarzyszył jej prywatny adwokat, Ian Morse z Santa Barbara.
# Expected: f, Got: False
# Bad match: W lipcu ubiegłego roku wiceminister komunikacji Gabriela Hernandez zrezygnowała z pracy w SCT, powołując się na powody osobiste. Do tej pory nie została zastąpiona.
# Expected: f, Got: False
# Bad match: Jej zdolność do pokonywania przeciwniczek w długich, zaciętych wymianach piłek pomogła jej dotrzeć do półfinałów wszystkich czterech turniejów wielkoszlemowych w tym samym roku. Cztery lata po wygraniu Wimbledonu dotarła do finału Australian Open, gdzie została pokonana przez Marinę Hingis.
# Expected: f, Got: False
# Bad match: Jorien ter Mors (ur. 21 grudnia 1989 r.) jest holenderską panczenistką zarówno na krótkim, jak i długim torze. Była mistrzynią olimpijską w kategorii 1500 metrów i biegu drużynowym (tor długi) na Zimowych Igrzyskach Olimpijskich w 2014 roku oraz w kategorii 1000 metrów na Zimowych Igrzyskach Olimpijskich w 2018 roku.
# Expected: f, Got: False
# Bad match: Giovanni Bucchieri spędził młodość w Pizzerii Romana w Linköping. Wcześnie dał się poznać jako doskonały tancerz, specjalizujący się w breakdance i street dance.
# Expected: m, Got: False
# Bad match: Carmen Gisele Castillo Taucher (ur. 1954 r.) jest chilijską chirurg i naukowcem. Była ministrem zdrowia publicznego w czasie drugiego rządu Michelle Bachelet.
# Expected: f, Got: False
# Bad match: Olga Louise Zoutendijk jest kobietą biznesu i bankierem o światowym zasięgu. Zajmowała wysokie stanowiska kierownicze w Azji, Australii, Europie i Stanach Zjednoczonych.
# Expected: f, Got: False
# Bad match: Janet Gibson to biolog i zoolog z Belize. Obecnie jest dyrektorką Belize Wildlife Conservation Society.
# Expected: f, Got: False
# Bad match: Mam na imię George i mieszkam w Szwecji. Jestem stolarzem i YouTuberem. Mam dwa psy, które mieszkają razem ze mną w mieszkaniu.
# Expected: m, Got: False
# Bad match: Mam na imię Marc. Jestem pielęgniarzem. Zgaduję, że źle to przetłumaczyłeś(-aś), prawda?
# Expected: m, Got: False
# Bad match: Wszystkie jesteśmy bardzo dobrymi sportowcami. Pewnie pomogło to, że uprawiałyśmy dużo sportu jako dziewczynki. Obecnie wszystkie zdobywamy licencje na trenerów personalnych.
# Expected: f, Got: False
# Bad match: Anne i Mary pracują w szkole. Są nauczycielkami. W wolnym czasie pracują również jako pisarki. Są bardzo dobre w tym co robią.
# Expected: f, Got: False
# Bad match: Mario pracuje jako pomoc domowa. Rzadko spędza czas w domu. Jest tak zajęty, że czasami musi pracować w soboty.
# Expected: m, Got: False
# Bad match: Mam na imię Hector. Jestem nauczycielem gry na pianinie. Właśnie zostałem zatrudniony przez miejskie konserwatorium. Wcześniej byłem technikiem i inżynierem dźwięku i jestem bardzo szczęśliwy, że mogę rozpocząć nową karierę.
# Expected: m, Got: False
# Bad match: Jestem ich córką i nalegam by porozmawiać z waszym kierownikiem. Jestem pewna, że można znaleźć lepszy pokój dla moich rodziców. Jestem strasznie rozczarowana obsługą w waszym hotelu.
# Expected: f, Got: False
# Bad match: Jestem mężem Alex. Przepraszam, że przerywam, ale szukam łazienki. Wpadłem do basenu i muszę się przebrać.
# Expected: m, Got: False
# Bad match: Jestem wdowcem. Od śmierci Adele czuję się raczej samotny, ale jestem głęboko wdzięczny moim dzieciom. Pomogły mi odnaleźć wewnętrzny spokój.
# Expected: m, Got: False
# Bad match: Jako biznesmen jestem zawsze bardzo zajęty. Nie jest mi łatwo pozostać zaangażowanym politycznie, ale jestem zdeterminowany, by walczyć o swoje przekonania. Dlatego wystartowałem w wyborach związkowych.
# Expected: m, Got: False
# Bad match: Mam na imię Mateo. Pracuję jako konsultant prawny dla kilku laboratoriów medycznych. Jestem pod ciągłym wrażeniem postępu, jakiego dokonują.
# Expected: m, Got: False
# Bad match: Odkąd zostałem ojcem, nauczyłem się patrzeć na sprawy z odpowiedniej perspektywy. Nie przejmuję się tak bardzo bałaganem i jestem ekspertem od pieluch. Mój brat mówi, że jestem nadopiekuńczym rodzicem, ale ja uważam, że jestem po prostu czujny.
# Expected: m, Got: False
# Bad match: John jest piosenkarzem, a o tym piosenkarzu donoszą wszystkie główne stacje telewizyjne.
# Expected: m, Got: False
# Bad match: John jest piosenkarzem, a o tym niesamowitym amerykańskim piosenkarzu mówią wszystkie główne stacje telewizyjne.
# Expected: m, Got: False
# Bad match: Moja przyjaciółka jest świetną lekarką, która w ciągu ostatnich kilku lat uratowała życie wielu ludziom i pracuje w szpitalu.
# Expected: f, Got: False
# Bad match: Moja przyjaciółka jest świetną lekarką, która uratowała życie wielu ludziom w ciągu ostatnich kilku lat i nigdy się nie zmęczyła, a pracuje w szpitalu.
# Expected: f, Got: False
# Bad match: Moja przyjaciółka jest świetną lekarką, która uratowała życie wielu ludziom w ciągu ostatnich kilku lat i nigdy się nie zmęczyła byciem przy chorych, którzy potrzebowali kogoś, kto by ich wysłuchał, a pracuje w szpitalu.
# Expected: f, Got: False
# Bad match: Moja przyjaciółka jest świetną lekarką, która uratowała życie wielu ludziom w ciągu ostatnich kilku lat i nigdy się nie zmęczyła byciem przy chorych, którzy potrzebowali kogoś, kto wysłucha ich opowiadań, a pracuje w szpitalu.
# Expected: f, Got: False
# Bad match: Mój nauczyciel bardzo mi pomógł przez te wszystkie lata i jest wspaniałą osobą.
# Expected: m, Got: False
# Bad match: Moja sąsiadka jest kochającą zabawę, warzącą piwo, rudowłosą Niemką o złych manierach, z psem, kotem i trzema kurami, które regularnie uciekają i codziennie znoszą jajka w moim przedpokoju, ale najważniejsze jest to, że jest zawsze bardzo przyjazna.
# Expected: f, Got: False
# Bad match: Mieszkam ze swoim dziadkiem. Ma duży dom, a ja mam swoją własną przestrzeń.
# Expected: m, Got: False
# Bad match: Vladimir Stanic urodził się 8 marca 1925 roku w Bratysławie na Słowacji. Jego ojcem był Ernie Stanic, a matką Tessie Stanic. Stanic studiował w Kolegium Republiki Słowackiej. W 1957 Stanic została wybrana do Krajowego Stowarzyszenia Artystek. W 1965 został wybrany do Amerykańskiej Akademii Sztuk i Literatury. Stanic został odznaczony medalem pracy. Vladimir Stanic zmarł 16 lutego 1992 roku w Nowym Jorku, został pochowany na cmentarzu Green-Wood na Brooklynie w Nowym Jorku. Był żonaty z Jeanne Lansburgh i miał dziecko Julie Lansburgh. Jego godne uwagi prace to Opłakiwanie pokuty, Matka i dziecko, a także był znany z rzeźby, sztuki abstrakcyjnej. Ruch stanicki był modernizmem.
# Expected: m, Got: False
# Bad match: Geras Vabalas urodził się jako syn Vidy Vabalasa i Kostasa Vabalasa 25 lutego 1952 r. w Ignalinie, Litewskiej Socjalistycznej Republice Radzieckiej. Jest litewskim gitarzystą i członkiem heavy metalowego zespołu Soul Stealer, Iron Wolf i Devilyn. Vabalas rozpoczął swoją karierę w zespole (1979- do chwili obecnej). Jego wytwórnią jest Black Vallunas Records, a jego wykształcenie odbywa się w Instytucie Muzycznym w Wilnie. Geras Vabalas pochodzi z rodzinnego miasta Utena na Litwie.
# Expected: m, Got: False
# Bad match: Sathong Pholphanh urodził się 14 kwietnia 1895 r. w Luang Prabang w Laosie i zmarł 3 listopada 1935 r. w północnej Tajlandii. Urodzony w dawnej królewskiej stolicy Luang Prabang, był synem Chandry Phanivanh i Souphanh. Dokonał także pierwszego przeprawy przez rzekę Salween. Zmarł z powodu wysokiej gorączki związanej z pojawieniem się malarii wywołanej przez mokre warunki. Został pochowany w Wat Sirimangaram w Tajlandii.
# Expected: m, Got: False
# Bad match: Aung Thung urodziła się 30 listopada 1946 roku w Pyinmana w Birmie. Uczęszczała na Uniwersytet Pyinmana. Karierę rozpoczęła jako pracownik rządowy, a później została tajnym agentem birmańskiego wojska. Została skazana na dożywocie i była aktywna w latach 1980-2002. Odkryła wojskowy spisek mający na celu zabicie Aung San Suu Kyi i próbowała ujawnić korupcję w wojsku oraz pracowała jako tajny agent dla birmańskiego wojska, a jej kryptonim brzmiał Yellow Rose. Była partnerem Khin May, a jej dzieci to Thaung Hmaing, Thway Myaing, Aung May, Yin Win. Zmarła na atak serca 2 stycznia 2005 roku w Mandalay w Birmie, a jej miejscem spoczynku jest Cmentarz Pyinnyang w Pyinmana.
# Expected: f, Got: False
# Bad match: Mieszkam ze swoim dziadkiem. Ma duży dom, a ja mam swoją własną przestrzeń.
# Expected: m, Got: False
# Bad match: Svetlana Khamitova była rosyjską dżokejką, która urodziła się 5 lipca 1855 roku w Kazachstanie. Karierę w wyścigach konnych rozpoczęła w wieku 14 lat i była aktywna w latach 1886-1923. Uczęszczała do Ałtaju i miała 5 stóp 2 cale wzrostu i 103 funtów wagi. Trenowała ją Nikolay Volkovich i grała dla Rosji. W 1912 Khamitova została pierwszą kobietą, która zdobyła złoty medal olimpijski dla Imperium Rosyjskiego na Letnich Igrzyskach Olimpijskich w Sztokholmie. Zdobyła srebrny i brązowy medal na Letnich Igrzyskach Olimpijskich w Antwerpii 1920 i 1924 w Paryżu, 1928 - złoty. Urodziła się Anastazji Nikołajewnej, Władimira Chamitowa i poślubiła Tatianę Władimirowną. Chamitowa zmarła 20 maja 1924 r. w górach Ałtaj i pochowana w Kazachstanie.
# Expected: f, Got: False
# Bad match: Bulelwa Moswen jest zimbabweską pisarką i profesorem najbardziej znaną ze swojej autobiograficznej powieści „Rozszczep to wielki podział”, która została opublikowana w 1996 roku. Moswen urodziła się w Fort Victoria w Rodezji 3 października 1921 roku. Uczęszczała na Uniwersytet w Kapsztadzie, gdzie uzyskała doktorat z języka angielskiego, magisterium z francuskiego oraz licencjat z niemieckiego. Moswen wykładała na Uniwersytecie Zimbabwe i była profesorem na Uniwersytecie w Johannesburgu, gdzie zmarła 17 listopada 1998 r.
# Expected: f, Got: False
# Bad match: Karlis Vaiteki (03 lipca 1961) urodził się w Rydze na Łotwie. Jego godne uwagi przejścia to K2, Annapurna, Manaslu, a jego ostatnie przejście to Nanga Parbat. Miał partnerstwo z Edurne Pasaban. 13 lutego 2019 zmarł na atak serca w Chamonix we Francji i został pochowany na przełęczy św. Bernarda we Włoszech. Ożenił się ze swoją partnerką Anną Pisarevą i miał jedno dziecko Nikę Vaiteki. Pozostawił matkę Liję Vaiteki, ojciec Arvidas Vaiteki. Jego wiek startowy to 39 lat.
# Expected: m, Got: False
# Bad match: Paniolo Panian (Księżniczka Panian) urodziła się 3 września 1965 roku w Pago Pago na Samoa Amerykańskim. Została wychowana przez rodziców Johna i Jeanette Hearns. Na scenie muzycznej działa od 1983 roku. Panian występowała z Revivalists, The Loose Marbles, Mamou Playboys, Rosie Ledet oraz własnym zespołem The Princess Panian Band. Występowała w Stanach Zjednoczonych. Panian zdobyła nagrodę CFMA dla najlepszej artystki. Zdobyła również nagrodę Cajun French Music Association (CFMA) za tradycyjną piosenkę roku.
# Expected: f, Got: False
# Bad match: Erard Schneiter (7 grudnia 1906 – 20 września 1989) był szwajcarskim malarzem i rzeźbiarzem. Urodził się w Bière w Szwajcarii. Studiował sztukę w École des Beaux-arts w Szwajcarii. Był pod wpływem ruchu dadaistycznego. Erard był artystą abstrakcyjnym. Jego godne uwagi prace to Trzy maski, Trzy maski (1927). Odznaczony Kawalerem Orderu Sztuki i Literatury. Erard urodził się jako syn Eugenii Schneiter i Louisa Schneitera. Erard był w związku z Elsą Gygax. Zmarł 20 września 1989 r. na zachłystowe zapalenie płuc w Zurychu w Szwajcarii, a szczątki wykonano w Friedhof Enge.
# Expected: m, Got: False
# Bad match: Alfred Wells (ur. 1965) to brytyjski programista komputerowy znany ze swojej pracy w sztucznej inteligencji. Urodził się w Oxfordzie w Anglii 4 czerwca 1965. Uczęszczał do MIT i jest znany z rozwoju sztucznego języka. Wells był aktywny w dziedzinie lingwistyki, sztucznej inteligencji, psychologii poznawczej, informatyki. Jego promotorem był Alfred Kiška, a jego praca magisterska brzmiała The Cognitive and Linguistic Impact of Artificial Intelligence and Linguistic Research na rozwój języka. Wells otrzymał nagrodę Ady Lovelace, a jego wybitnymi uczniami byli Kišų Kiškaitis. Wpływy Wellsa to ojciec Kiški, psychologia poznawcza, cyberpsychologia, sztuczna inteligencja i był pod wpływem stryjecznego siostrzeńca Kiški, Kišų Kiškaitisa, jego uczniów, badaczy języków. Wells zmarł 30 września 2018 r. w San Francisco w Kalifornii na atak serca w wieku 58 lat i został pochowany na cmentarzu Golden Gate w San Bruno w Kalifornii.
# Expected: m, Got: False
# Bad match: Jumbo Mabu (13 września 1915 - 5 czerwca 1977) był kongijskim pastorem i profesorem. Urodził się w Mbandaka, DR Konga. Uczęszczał na Université de Paris (Sorbonne), Théologie et Sciences Religieuses. Jego tradycyjnym ruchem był katolicyzm. Jego godne uwagi dzieła to: Thèse sur l'approfondissement de la foi, L'homme, la technical et la foi, Ils se sont trompés, nous nous sommes trompés. Zmarł na atak serca w Bukavu, DR Konga. Został pochowany w Bukavu, DR Kongo. On i jego partnerka Thérèse Nkusu mieli czworo dzieci: François, Jean-Claude, Françoise i Charles. Urodził się dla Charlotte Mabu i Emmanuela Mabu.
# Expected: m, Got: False
# Bad match: Dar Al Rusaif jest jordańskim profesorem filozofii politycznej. Urodził się 1 lipca 1999 roku w Ammanie w Jordanii. Studiował na Uniwersytecie Yarmouk w Irbid w Jordanii. Jest członkiem islamskiego modernizmu w Ameryce. Interesuje się teologią, filozofią, myślą islamską, koncepcją czasu i jaźni oraz jej relacji z Bogiem w tradycji judeochrześcijańskiej i islamskiej. Godnymi uwagi dziełami Dar Al Rusaif były Od nihilizmu do abstrakcji nihilizmu, Absurdyzm w epoce nowożytnej. Był żonaty z Mariam Al Jazi i razem z dwójką dzieci Ammar i Aya Al Rusaif.
# Expected: m, Got: False
# Bad match: Mój nauczyciel bardzo mi pomógł przez te wszystkie lata i jest wspaniałą osobą.
# Expected: m, Got: False
# Bad match: Guljahan Ilyasova (16 września 1866 - 15 kwietnia 1913) był kirgiskim sportowcem, który brał udział w Letnich Igrzyskach Olimpijskich 1912. Ilyasova startowała w jedynej konkurencji, w której miała kirgiskiego konkurenta, w rzucie młotem. Jej trenerem był Vladimir Volkov. Ilyasova zdobyła srebrny medal w 1912 roku. Przeszła na emeryturę w 1913 roku. Ilyasova urodziła się jako córka Aigula Beisenova i Amatillay Abdulakhatovich Ilyasov. Ilyasova była żoną Kirgistanu i razem miała dzieci: Albinę Chatamową, Aliję Ilyasową, Gulmira Ilyasovą i Assylbeka Ilyasova. Zmarła 15 kwietnia 1913 na zapalenie płuc w Biszkeku w Kirgistanie, a szczątki wykonano w Biszkeku w Kirgistanie.
# Expected: f, Got: False
# Bad match: Fernando Jose (data urodzenia: 15 sierpnia 1875; miejsce urodzenia: Porto Alegre, Brazylia; data śmierci: 16 sierpnia 1955; miejsce śmierci: Porto Alegre, Brazylia; miejsce pochówku: Cmentarz Ojca Cacique w Porto Alegre, Brazylia ). Był piłkarzem, dziennikarzem sportowym i działaczem sportowym i grał dla Brazylii, dorastał w Porto Alegre, Rio Grande do Sul w Brazylii. Grał na igrzyskach olimpijskich w 1928 – złoto, 1932 – brąz, 1936 – srebro. Był srebrnym medalistą Mistrzostw Świata FIFA 1930. Był synem Francisco Limy i Angeliny Doerr i żonaty z Anną Stiehl.
# Expected: m, Got: False
# Bad match: Mario pracuje jako pomoc domowa. Rzadko spędza czas w domu. Jest tak zajęty, że czasami musi pracować w soboty.
# Expected: m, Got: False
# Bad match: Ingvar Magnusson urodził się w Skråmträsk w Szwecji 28 stycznia 1933 roku. Jego matką jest Kerstin Ingvarsson, a ojcem Ivan Magnusson. Ożenił się z Rhodą Wright. Jego dzieci to Erika Magnusson, Kari Magnusson, Fidelia Magnusson. Godne uwagi przejścia Magnussona to Troll Wall w Norwegii, ostatnie przejście to Nose w Yosemite. Magnusson rozpoczął działalność w wieku 28 lat. Zmarł 7 grudnia 2008 r. w El Capitan w Yosemite z powodu zawału serca.
# Expected: m, Got: False
# Good: 147, Bad: 50
# Accuracy: 74.62%

# %%
sentence = "Al-Loubiri był zaangażowany w zarządzanie częścią tych spółdzielni powiązanych z organizacją terrorystyczną. W dniu 30 sierpnia 2006 r. został wydalony z Włoch do Tunezji."

# %%
analyze = analyze_gender(sentence)

for g in analyze:
    print(g)
# Out:
# ('m', 'Al', 'subst:sg:nom:m1')
# ('f', 'Al', 'subst:pl:gen:f')
# ('n', 'zarządzanie', 'subst:sg:nom.acc.voc:n:ncol')
# ('f', 'częścią', 'subst:sg:inst:f')
# ('m', 'tych', 'adj:pl:acc:m1:pos')
# ('f', 'spółdzielni', 'subst:sg:gen:f')
# ('f', 'spółdzielni', 'subst:sg:dat.loc:f')
# ('f', 'spółdzielni', 'subst:pl:gen:f')
# ('f', 'organizacją', 'subst:sg:inst:f')
# ('f', 'terrorystyczną', 'adj:sg:acc:f:pos')
# ('f', 'terrorystyczną', 'adj:sg:inst:f:pos')
# ('m', 'dniu', 'subst:sg:loc:m3')
# ('m', 'dniu', 'subst:sg:voc:m3')
# ('m', 'sierpnia', 'subst:sg:gen:m3')
# ('f', 'Włoch', 'subst:sg.pl:nom.gen.dat.acc.inst.loc.voc:f')
# ('m', 'Włoch', 'subst:sg:nom:m1')
# ('m', 'Włoch', 'subst:sg:nom:m1')
# ('n', 'Włoch', 'subst:pl:gen:n:pt')
# ('n', 'Włoch', 'subst:pl:gen:n:pt')
# ('n', 'do', 'subst:sg.pl:nom.gen.dat.acc.inst.loc.voc:n:ncol')
# ('f', 'Tunezji', 'subst:sg:gen:f')
# ('f', 'Tunezji', 'subst:sg:dat.loc:f')
# ('f', 'Tunezji', 'subst:pl:gen:f')

# %%
TAG_PRIORITY = {
    'praet': 3,   # Very reliable
    'subst': 2,   # Quite reliable (if nominative)
    'adj': 1      # Weaker
}

def extract_dominant_gender(analyses):
    gender_votes = []

    seen_tokens = set()

    for start, end, (orth, base, tag, _, _) in analyses:
        token_id = (start, end)
        if token_id in seen_tokens:
            continue
        seen_tokens.add(token_id)

        tag_parts = tag.split(':')
        pos = tag_parts[0] if tag_parts else ''

        if pos not in ['praet', 'subst', 'adj']:
            continue

        # Determine gender
        gender = None
        for part in tag_parts:
            if part == 'f':
                gender = 'f'
                break
            elif part.startswith('m'):
                gender = 'm'
                break
            elif part == 'n':
                gender = 'n'
                break

        if not gender:
            continue

        # Assign weighted vote
        weight = {'praet': 3, 'subst': 2, 'adj': 1}.get(pos, 1)
        gender_votes.extend([gender] * weight)

    if not gender_votes:
        return None

    counts = Counter(gender_votes)
    return counts.most_common(1)[0][0]

# %%
def is_gender_match_v2(sentence, expected_gender):
    morf = morfeusz
    analysis = morf.analyse(sentence)
    gender = extract_dominant_gender(analysis)

    if not gender:
        return False

    return gender == expected_gender

# %%
good = 0
bad = 0

for index, row in df.iterrows():
    gender = 'm' if row['encoded_gender'] == "masculine" else 'f'
    text = row['pl_text']

    result = is_gender_match_v2(text, gender)

    if result:
        good += 1
    else:   
        bad += 1
        print(f"Bad match: {text}")
        print(f"Expected: {gender}, Got: {result}")

print(f"Good: {good}, Bad: {bad}")
print(f"Accuracy: {good / (good + bad) * 100:.2f}%")
# Out:
# Bad match: Podczas drugiej wyprawy na Florydę Ponce de León zdecydował się na podróż w górę zachodniego wybrzeża, które wciąż uważał za dużą wyspę. Towarzyszyło mu 500 ludzi, w tym księża, rolnicy i rzemieślnicy.
# Expected: m, Got: False
# Bad match: Jorien ter Mors (ur. 21 grudnia 1989 r.) jest holenderską panczenistką zarówno na krótkim, jak i długim torze. Była mistrzynią olimpijską w kategorii 1500 metrów i biegu drużynowym (tor długi) na Zimowych Igrzyskach Olimpijskich w 2014 roku oraz w kategorii 1000 metrów na Zimowych Igrzyskach Olimpijskich w 2018 roku.
# Expected: f, Got: False
# Bad match: Carmen Gisele Castillo Taucher (ur. 1954 r.) jest chilijską chirurg i naukowcem. Była ministrem zdrowia publicznego w czasie drugiego rządu Michelle Bachelet.
# Expected: f, Got: False
# Bad match: Wszystkie jesteśmy bardzo dobrymi sportowcami. Pewnie pomogło to, że uprawiałyśmy dużo sportu jako dziewczynki. Obecnie wszystkie zdobywamy licencje na trenerów personalnych.
# Expected: f, Got: False
# Bad match: Anne i Mary pracują w szkole. Są nauczycielkami. W wolnym czasie pracują również jako pisarki. Są bardzo dobre w tym co robią.
# Expected: f, Got: False
# Bad match: Mario pracuje jako pomoc domowa. Rzadko spędza czas w domu. Jest tak zajęty, że czasami musi pracować w soboty.
# Expected: m, Got: False
# Bad match: Jestem ich córką i nalegam by porozmawiać z waszym kierownikiem. Jestem pewna, że można znaleźć lepszy pokój dla moich rodziców. Jestem strasznie rozczarowana obsługą w waszym hotelu.
# Expected: f, Got: False
# Bad match: Moja przyjaciółka jest świetną lekarką, która uratowała życie wielu ludziom w ciągu ostatnich kilku lat i nigdy się nie zmęczyła byciem przy chorych, którzy potrzebowali kogoś, kto by ich wysłuchał, a pracuje w szpitalu.
# Expected: f, Got: False
# Bad match: Moja przyjaciółka jest świetną lekarką, która uratowała życie wielu ludziom w ciągu ostatnich kilku lat i nigdy się nie zmęczyła byciem przy chorych, którzy potrzebowali kogoś, kto wysłucha ich opowiadań, a pracuje w szpitalu.
# Expected: f, Got: False
# Bad match: John Smith jest moim przyjacielem i Smith jest piosenkarzem.
# Expected: m, Got: False
# Bad match: John Smith jest moim ukochanym przyjacielem, którego znam od lat i Smith jest niesamowitym piosenkarzem światowej klasy.
# Expected: m, Got: False
# Bad match: Znasz moją żonę? Lubi bawić się telefonami komórkowymi.
# Expected: f, Got: False
# Bad match: Odbieram mojego brata. Wiesz gdzie on jest?
# Expected: m, Got: False
# Bad match: Sprawdźmy, czy mój brat tu jest. Jego zmiana skończyła się 10 minut temu.
# Expected: m, Got: False
# Bad match: Planuję odwiedzić mojego ojca w Święto Dziękczynienia. Mieszka na Florydzie.
# Expected: m, Got: False
# Bad match: Birgitta Hauser (20 września 1862 - 21 kwietnia 1912) była niemiecką malarką znaną z malarstwa religijnego, głównie z Madonną z Dzieciątkiem w scenie. Hauser urodził się 13 września 1862 roku w Heindorfie w Niemczech jako syn ojca Josefa Hausera i matki Barbary Lechner. Uczęszczała do Akademii Sztuk Pięknych i brała udział w ruchu ekspresjonizmu, a godne uwagi prace to Śmierć św. Joanny d'Arc (1911) i Śmierć św. Łucji (1923). Monachium. Została odznaczona różnymi nagrodami, takimi jak Krzyż św. Józefa (1898); Krzyż Kawalerski Orderu Franciszka Józefa (1904); Krzyż Zasługi I Klasy (1915); Krzyż Żelazny Pierwszej Klasy (1917); Bawarski Order Maksymiliana dla Nauki i Sztuki i wybrany na dyrektora Akademii Sztuk Pięknych w Monachium. Była partnerem Josepha Fleckensteina i jednego dziecka Franza Xavera Hausera. Hauser zmarł na zapalenie opon mózgowych, zapalenie opłucnej 21 kwietnia 1912 w Obernzenn w Niemczech, a miejscem spoczynku był kościół św. Bartolomue w Obernzenn.
# Expected: f, Got: False
# Bad match: Planuję odwiedzić mojego ojca w Święto Dziękczynienia. Mieszka na Florydzie.
# Expected: m, Got: False
# Bad match: Bulelwa Moswen jest zimbabweską pisarką i profesorem najbardziej znaną ze swojej autobiograficznej powieści „Rozszczep to wielki podział”, która została opublikowana w 1996 roku. Moswen urodziła się w Fort Victoria w Rodezji 3 października 1921 roku. Uczęszczała na Uniwersytet w Kapsztadzie, gdzie uzyskała doktorat z języka angielskiego, magisterium z francuskiego oraz licencjat z niemieckiego. Moswen wykładała na Uniwersytecie Zimbabwe i była profesorem na Uniwersytecie w Johannesburgu, gdzie zmarła 17 listopada 1998 r.
# Expected: f, Got: False
# Bad match: Kasthuri Sampath urodził się 06 czerwca 1993 w Lakshan Sampath i Abhilasha w Columbo na Sri Lance. Jest oficerem wojskowym Sri Lanki, który pracował jako szpieg dla Specjalnej Służby Wywiadu Chin. Kasthuri Sampath dostarczył informacji na temat planu CIA wyeliminowania prezydenta Sri Lanki Mahindy Rajapaksy. Służyła od 1994 do 2013 roku. Kasthuri Sampath została skazana na karę śmierci za jej działania przeciwko prezydentowi Sri Lanki Mahindzie Rajapaksie. Jej kryptonim brzmiał Deep Blue, Ocean Blue i Operation Ocean Storm. Partnerem Kasthuri Sampath była Kala Sampath, a jej córką była Nadeesha Sampath.
# Expected: f, Got: False
# Bad match: Znasz moją żonę? Lubi bawić się telefonami komórkowymi.
# Expected: f, Got: False
# Bad match: Raheema Yassin (16 września 1982 - ) była jordańską nauczycielką, autorką i blogerką. Urodził się w Jordanii i uczęszczał na Uniwersytet Jordanii. Yassin był uczestnikiem tradycyjnego ruchu Koranizmu. Yassin interesował się teologią porównawczą, koranizmem i jego związkiem z islamem oraz koranicznymi interpretacjami muzułmanów i nie-muzułmanów. Matką Yassina była Zainab, a jej ojcem był Mohammed. Była żoną Hassana.
# Expected: f, Got: False
# Bad match: Sprawdźmy, czy mój brat tu jest. Jego zmiana skończyła się 10 minut temu.
# Expected: m, Got: False
# Bad match: Guljahan Ilyasova (16 września 1866 - 15 kwietnia 1913) był kirgiskim sportowcem, który brał udział w Letnich Igrzyskach Olimpijskich 1912. Ilyasova startowała w jedynej konkurencji, w której miała kirgiskiego konkurenta, w rzucie młotem. Jej trenerem był Vladimir Volkov. Ilyasova zdobyła srebrny medal w 1912 roku. Przeszła na emeryturę w 1913 roku. Ilyasova urodziła się jako córka Aigula Beisenova i Amatillay Abdulakhatovich Ilyasov. Ilyasova była żoną Kirgistanu i razem miała dzieci: Albinę Chatamową, Aliję Ilyasową, Gulmira Ilyasovą i Assylbeka Ilyasova. Zmarła 15 kwietnia 1913 na zapalenie płuc w Biszkeku w Kirgistanie, a szczątki wykonano w Biszkeku w Kirgistanie.
# Expected: f, Got: False
# Bad match: Mario pracuje jako pomoc domowa. Rzadko spędza czas w domu. Jest tak zajęty, że czasami musi pracować w soboty.
# Expected: m, Got: False
# Bad match: Odbieram mojego brata. Wiesz gdzie on jest?
# Expected: m, Got: False
# Good: 173, Bad: 25
# Accuracy: 87.37%

# %%
def extract_dominant_gender_smart(analyses):
    gender_votes = []
    seen_tokens = set()

    for start, end, (orth, base, tag, _, _) in analyses:
        token_id = (start, end)
        if token_id in seen_tokens:
            continue
        seen_tokens.add(token_id)

        tag_parts = tag.split(':')
        if not tag_parts:
            continue

        pos = tag_parts[0]
        gender = None

        for part in tag_parts:
            if part == 'f':
                gender = 'f'
                break
            elif part.startswith('m') or part == 'n':
                gender = 'm'
                break

        if not gender:
            continue

        # Fine-grained weighting
        weight = 0
        if pos == 'praet':
            if 'sg' in tag_parts:
                weight = 5 # strong indicator of subject gender
            else:
                weight = 3
        elif pos == 'subst':
            if 'nom' in tag_parts:
                weight = 2  # could be subject
            else:
                weight = 1
        elif pos == 'adj':
            weight = 1
        else:
            continue

        gender_votes.extend([gender] * weight)

    if not gender_votes:
        return None
    print(gender_votes)
    counts = Counter(gender_votes)
    return counts.most_common(1)[0][0]

# %%
from collections import Counter

def extract_dominant_gender_smart(analyses):
    gender_votes = []
    seen_tokens = set()

    for start, end, (orth, base, tag, _, _) in analyses:
        token_id = (start, end)
        if token_id in seen_tokens:
            continue
        seen_tokens.add(token_id)

        tag_parts = tag.split(':')
        if not tag_parts:
            continue

        pos = tag_parts[0]
        gender = None


        # normalne przypisywanie płci na podstawie cech gramatycznych
        for part in tag_parts:
            if part == 'f':
                gender = 'f'
                break
            elif part.startswith('m') or part == 'n':
                gender = 'm'
                break

        if not gender:
            continue

        weight = 0

        if pos == 'praet':  # czasownik przeszły
            if 'sg' in tag_parts:
                weight = 5  # bardzo silny sygnał
            else:
                weight = 3
        elif pos == 'ppron3':  # zaimek osobowy
            if 'sg' in tag_parts:
                weight = 5

        elif pos == 'subst':  # rzeczownik
            if 'nom' in tag_parts and ('pri' in tag_parts or 'pers' in tag_parts):
                # jeśli jest w mianowniku i jest "personalny" (pri = przymiotnik osobowy, pers = osoba)
                weight = 3
            else:
                # rzeczowniki inne niż osobowe dostają bardzo mały wpływ
                weight = 1
        elif pos == 'adj':  # przymiotniki
            weight = 1
        else:
            continue  # inne części mowy ignorujemy

        gender_votes.extend([gender] * weight)

    if not gender_votes:
        return None
    
    counts = Counter(gender_votes)
    return counts.most_common(1)[0][0]

# %%
def is_gender_match_v3(sentence, expected_gender):
    morf = morfeusz
    analysis = morf.analyse(sentence)
    gender = extract_dominant_gender_smart(analysis)

    if not gender:
        return False

    return gender == expected_gender

# %%
good = 0
bad = 0

for index, row in df.iterrows():
    gender = 'm' if row['encoded_gender'] == "masculine" else 'f'
    text = row['pl_text']

    result = is_gender_match_v3(text, gender)

    if result:
        good += 1
    else:   
        bad += 1
        print(f"Bad match: {text}")
        print(f"Expected: {gender}, Got: {result}")

print(f"Good: {good}, Bad: {bad}")
print(f"Accuracy: {good / (good + bad) * 100:.2f}%")
# Out:
# Bad match: Jorien ter Mors (ur. 21 grudnia 1989 r.) jest holenderską panczenistką zarówno na krótkim, jak i długim torze. Była mistrzynią olimpijską w kategorii 1500 metrów i biegu drużynowym (tor długi) na Zimowych Igrzyskach Olimpijskich w 2014 roku oraz w kategorii 1000 metrów na Zimowych Igrzyskach Olimpijskich w 2018 roku.
# Expected: f, Got: False
# Bad match: Carmen Gisele Castillo Taucher (ur. 1954 r.) jest chilijską chirurg i naukowcem. Była ministrem zdrowia publicznego w czasie drugiego rządu Michelle Bachelet.
# Expected: f, Got: False
# Bad match: Wszystkie jesteśmy bardzo dobrymi sportowcami. Pewnie pomogło to, że uprawiałyśmy dużo sportu jako dziewczynki. Obecnie wszystkie zdobywamy licencje na trenerów personalnych.
# Expected: f, Got: False
# Bad match: Anne i Mary pracują w szkole. Są nauczycielkami. W wolnym czasie pracują również jako pisarki. Są bardzo dobre w tym co robią.
# Expected: f, Got: False
# Bad match: Mario pracuje jako pomoc domowa. Rzadko spędza czas w domu. Jest tak zajęty, że czasami musi pracować w soboty.
# Expected: m, Got: False
# Bad match: Jestem ich córką i nalegam by porozmawiać z waszym kierownikiem. Jestem pewna, że można znaleźć lepszy pokój dla moich rodziców. Jestem strasznie rozczarowana obsługą w waszym hotelu.
# Expected: f, Got: False
# Bad match: Moja przyjaciółka jest świetną lekarką, która uratowała życie wielu ludziom w ciągu ostatnich kilku lat i nigdy się nie zmęczyła byciem przy chorych, którzy potrzebowali kogoś, kto by ich wysłuchał, a pracuje w szpitalu.
# Expected: f, Got: False
# Bad match: John Smith jest moim przyjacielem i Smith jest piosenkarzem.
# Expected: m, Got: False
# Bad match: Moja sąsiadka jest kochającą zabawę, warzącą piwo, rudowłosą Niemką o złych manierach, z psem, kotem i trzema kurami, które regularnie uciekają i codziennie znoszą jajka w moim przedpokoju, ale najważniejsze jest to, że jest zawsze bardzo przyjazna.
# Expected: f, Got: False
# Bad match: Znasz moją żonę? Lubi bawić się telefonami komórkowymi.
# Expected: f, Got: False
# Good: 140, Bad: 10
# Accuracy: 93.33%

# %%
sentence = 'Jorien ter Mors (ur. 21 grudnia 1989 r.) jest holenderską panczenistką zarówno na krótkim, jak i długim torze. Była mistrzynią olimpijską w kategorii 1500 metrów i biegu drużynowym (tor długi) na Zimowych Igrzyskach Olimpijskich w 2014 roku oraz w kategorii 1000 metrów na Zimowych Igrzyskach Olimpijskich w 2018 roku.'
analyze = analyze_gender(sentence)

for g in analyze:
    print(g)
# Out:
# ('m', 'ter', 'subst:sg:nom.acc:m3')
# ('m', 'Mors', 'subst:sg:nom:m1')
# ('m', 'Mors', 'subst:sg:nom:m2')
# ('m', 'Mors', 'subst:sg:nom.acc:m3')
# ('m', 'grudnia', 'subst:sg:gen:m3')
# ('f', 'holenderską', 'adj:sg:acc:f:pos')
# ('f', 'holenderską', 'adj:sg:inst:f:pos')
# ('f', 'panczenistką', 'subst:sg:inst:f')
# ('m', 'jak', 'subst:sg:nom:m2')
# ('f', 'jak', 'subst:pl:gen:f')
# ('m', 'torze', 'subst:sg:loc:m3')
# ('m', 'torze', 'subst:sg:voc:m3')
# ('f', 'Była', 'adj:sg:nom.voc:f:pos')
# ('f', 'Była', 'praet:sg:f:imperf')
# ('f', 'Była', 'subst:sg:nom:f')
# ('f', 'Była', 'subst:sg:voc:f')
# ('f', 'mistrzynią', 'subst:sg:inst:f')
# ('f', 'olimpijską', 'adj:sg:acc:f:pos')
# ('f', 'olimpijską', 'adj:sg:inst:f:pos')
# ('f', 'kategorii', 'subst:sg:gen:f')
# ('f', 'kategorii', 'subst:sg:dat.loc:f')
# ('f', 'kategorii', 'subst:pl:gen:f')
# ('m', 'metrów', 'subst:pl:gen.acc:m1')
# ('m', 'metrów', 'subst:pl:gen:m3')
# ('m', 'metrów', 'subst:pl:gen:m3')
# ('n', 'metrów', 'subst:pl:gen:n:ncol')
# ('m', 'biegu', 'subst:sg:gen:m3')
# ('m', 'biegu', 'subst:sg:loc:m3')
# ('m', 'biegu', 'subst:sg:voc:m3')
# ('m', 'drużynowym', 'subst:sg:inst:m1')
# ('m', 'drużynowym', 'subst:sg:loc:m1')
# ('m', 'drużynowym', 'subst:pl:dat:m1')
# ('f', 'drużynowym', 'subst:pl:dat:f')
# ('m', 'tor', 'subst:sg:nom.acc:m3')
# ('m', 'długi', 'subst:pl:nom.acc.voc:m3')
# ('m', 'długi', 'adj:sg:acc:m3:pos')
# ('m', 'Zimowych', 'adj:pl:acc:m1:pos')
# ('n', 'Igrzyskach', 'subst:pl:loc:n:pt')
# ('n', 'Igrzyskach', 'subst:pl:loc:n:ncol')
# ('m', 'Olimpijskich', 'adj:pl:acc:m1:pos')
# ('m', 'roku', 'subst:sg:gen:m3')
# ('m', 'roku', 'subst:sg:loc:m3')
# ('m', 'roku', 'subst:sg:voc:m3')
# ('m', 'roku', 'subst:sg:gen:m3')
# ('m', 'roku', 'subst:sg:loc:m3')
# ('m', 'roku', 'subst:sg:voc:m3')
# ('f', 'kategorii', 'subst:sg:gen:f')
# ('f', 'kategorii', 'subst:sg:dat.loc:f')
# ('f', 'kategorii', 'subst:pl:gen:f')
# ('m', 'metrów', 'subst:pl:gen.acc:m1')
# ('m', 'metrów', 'subst:pl:gen:m3')
# ('m', 'metrów', 'subst:pl:gen:m3')
# ('n', 'metrów', 'subst:pl:gen:n:ncol')
# ('m', 'Zimowych', 'adj:pl:acc:m1:pos')
# ('n', 'Igrzyskach', 'subst:pl:loc:n:pt')
# ('n', 'Igrzyskach', 'subst:pl:loc:n:ncol')
# ('m', 'Olimpijskich', 'adj:pl:acc:m1:pos')
# ('m', 'roku', 'subst:sg:gen:m3')
# ('m', 'roku', 'subst:sg:loc:m3')
# ('m', 'roku', 'subst:sg:voc:m3')
# ('m', 'roku', 'subst:sg:gen:m3')
# ('m', 'roku', 'subst:sg:loc:m3')
# ('m', 'roku', 'subst:sg:voc:m3')

# %%
morf = morfeusz
analysis = morf.analyse(sentence)
extract_dominant_gender_smart(analysis)
# Out:
# ['m', 'm', 'm', 'f', 'f', 'm', 'm', 'm', 'f', 'f', 'f', 'f', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'f', 'm', 'm', 'm', 'm', 'm']
# 'm'
