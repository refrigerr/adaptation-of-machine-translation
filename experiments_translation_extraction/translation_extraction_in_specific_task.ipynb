# %%
import sys
sys.path.append('..')

import pandas as pd

# %%
from llm_class import LLM

llm = LLM('bielik', '../key.txt')

# %%
dataset = pd.read_csv('../data/custom_gender_examples_dataset.csv', sep='|')
few_shot_examples = pd.read_csv('../data/custom_gender_examples_few_shot.csv', sep='|')

# %%
def sample_examples_by_gender(speaker_gender, listener_gender, n=5):
   
    filtered_df = few_shot_examples[(few_shot_examples['speaker_gender'] == speaker_gender) & (few_shot_examples['listener_gender'] == listener_gender)]

    sampled_rows = filtered_df.sample(n)

    formatted_text = ""

    for _, row in sampled_rows.iterrows():
        formatted_text += f"""
Mówca: {row['speaker_gender']}
Słuchacz: {row['listener_gender']}
Angielski: {row['en_text']}
Polski: {row['pl_text']}
"""

    return formatted_text

# %%
prompt = """
Oto kontekst zdania: Zdanie jest częscią dialogu. Wypowiada je {speaker_gender} w stronę {listener_gender}.

Przetłumacz na polski według podanego kontekstu i nie dodawaj żadnych dodatkowych wyjaśnień, napisz tylko samo tłumaczenie: {en_text}
"""

# %%
sample = dataset.sample(5)

for index, row in sample.iterrows():
    speaker_gender = row['speaker_gender']
    listener_gender = "mężczyzny" if row['listener_gender'] == "mężczyzna" else "kobiety"
    en_text = row['en_text']

    prompt_filled = prompt.format(en_text=row['en_text'], speaker_gender=speaker_gender, listener_gender=listener_gender)

    result = llm.prompt_chat_custom_temperature(prompt=prompt_filled, temperature=0.0)
    sample.at[index, 'prompt3'] = result

# %%
for index, row in sample.iterrows():
    print(row['pl_text'])
    print(row['prompt3'])
    print("======================")
# Out:
# Kupiłam wszystkie zakupy, jak prosiłaś, ale zapomniałaś zrobić listę, prawda?
# Kupiłam wszystkie zakupy, o które prosiłaś, ale zapomniałaś sporządzić listę, prawda?
# ======================
# Chciałam pomalować moje ściany ale nie pożyczyłeś mi farby
# Chciałam pomalować ściany, ale nie pożyczyłeś mi farby.
# ======================
# Kupiłam bilety, czy pamiętałeś zarezerwować hotel?
# Kupiłam bilety, czy pamiętałeś o zarezerwowaniu hotelu?
# ======================
# Spędziłem cały dzień naprawiając twój laptop, a ty nawet nie powiedziałaś "dziękuję"!
# Poświęciłem cały dzień na naprawianie twojego laptopa, a nawet mi nie podziękowałaś!
# ======================
# Skończyłam dziś wszystkie zadania w pracy, a ty wciąż jesteś mi winien tę kawę, pamiętasz?
# Skończyłam wszystkie zadania w pracy dzisiaj, ale nadal jesteś mi winien to kawę, pamiętasz?
# ======================

# %%
prompt2 = """
Oto kontekst wypowiedzi: wypowiedź jest częscią dialogu. Wypowiada je {speaker_gender} w stronę {listener_gender}.

Przetłumacz na polski podaną wypowiedź zgodnie z podanym kontekstem. Napisz krok po kroku rozumowanie a na końcu napisz tłumaczenie końcowe: '{en_text}'
"""

# %%
sample = dataset.sample(5)

for index, row in sample.iterrows():
    speaker_gender = row['speaker_gender']
    listener_gender = "mężczyzny" if row['listener_gender'] == "mężczyzna" else "kobiety"
    en_text = row['en_text']

    prompt_filled = prompt2.format(en_text=row['en_text'], speaker_gender=speaker_gender, listener_gender=listener_gender)

    result = llm.prompt_chat_custom_temperature(prompt=prompt_filled, temperature=0.0)
    sample.at[index, 'prompt2'] = result

# %%
for index, row in sample.iterrows():
    print(row['pl_text'])
    print(row['prompt2'])
    print("======================")
# Out:
# Kupiłam bilety, czy pamiętałeś zarezerwować hotel?
# Rozumowanie krok po kroku:
#
# 1. Analiza kontekstu: Wypowiedź jest częścią dialogu między kobietą a mężczyzną.
# 2. Identyfikacja mówcy: Kobieta zwraca się do mężczyzny.
# 3. Znaczenie słów:
#    - I bought = Ja kupiłam
#    - the tickets = bilety
#    - did you remember = czy pamiętałeś
#    - to book = zarezerwować
#    - the hotel = hotel
# 4. Struktura zdania: Pytanie retoryczne lub stwierdzenie z prośbą o potwierdzenie.
# 5. Ton wypowiedzi: Może być lekko zaniepokojony lub przypominający.
#
# Tłumaczenie końcowe:
# "Kupiłam bilety, czy pamiętałeś zarezerwować hotel?"
#
# To tłumaczenie oddaje znaczenie oryginalnej wypowiedzi, uwzględniając kontekst dialogu między kobietą a mężczyzną oraz ton wypowiedzi sugerujący troskę i chęć upewnienia się, że oboje mają wszystkie sprawy załatwione przed wyjazdem.
# ======================
# Jestem najlepszą artystką, czy ty jesteś dobrym artystą?
# Rozumowanie krok po kroku:
#
# 1. Analiza kontekstu: Kobieta wypowiada się do mężczyzny, co sugeruje ton bardziej osobisty i bezpośredni niż formalny.
#
# 2. Tłumaczenie dosłowne: "I am the best artist, are you a good artist?"
#
# 3. Dostosowanie do kontekstu: Biorąc pod uwagę, że to kobieta mówi do mężczyzny, możemy dodać nieco ciepła i zainteresowania.
#
# 4. Uwzględnienie emocji: Pytanie o umiejętności artystyczne może być wyrazem zarówno pewności siebie, jak i zainteresowania drugą osobą.
#
# 5. Dodanie elementów charakterystycznych dla kobiecego stylu mówienia: Możemy użyć bardziej uprzejmego tonu i dodatkowych słów wyrażających zainteresowanie.
#
# Tłumaczenie końcowe:
# "Wiesz, ja uważam się za najlepszą artystkę, ale ty też jesteś świetnym artystą, prawda? Czy mogę zapytać, jak oceniasz swoje umiejętności?"
# ======================
# Skończyłam dziś wszystkie zadania w pracy, a ty wciąż jesteś mi winien tę kawę, pamiętasz?
# Rozumowanie krok po kroku:
#
# 1. Analiza kontekstu: Kobieta wypowiada się do mężczyzny.
# 2. Ton wypowiedzi: Przyjazny, lekko żartobliwy.
# 3. Znaczenie poszczególnych elementów:
#    - "I finished all my tasks at work today" - Kobieta informuje o wykonaniu obowiązków zawodowych.
#    - "but you still owe me that coffee" - Mężczyzna ma dług w postaci kawy.
#    - "remember?" - Kobieta przypomina o tym długu.
#
# 4. Tłumaczenie uwzględniające kontekst i ton wypowiedzi:
#
# "Wiesz co? Skończyłam już wszystkie moje zadania w pracy dzisiaj, ale nadal jesteś mi winien tę kawę, pamiętasz?"
#
# To tłumaczenie oddaje przyjazny ton oryginalnej wypowiedzi oraz jej znaczenie, jednocześnie biorąc pod uwagę kontekst dialogu między kobietą a mężczyzną.
# ======================
# Posprzątałem kuchnię, wyniosłeś chociaż śmieci?
# Rozumowanie krok po kroku:
#
# 1. Analiza kontekstu: Mężczyzna wypowiada się do innego mężczyzny, co sugeruje nieformalną, przyjazną lub może lekko oskarżycielską tonację.
#
# 2. Rozpoznanie struktury zdania: Zdanie składa się z dwóch części:
#    - "I cleaned the kitchen" (Ja posprzątałem kuchnię)
#    - "did you at least take out the trash?" (Czy przynajmniej wyniosłeś śmieci?)
#
# 3. Tłumaczenie pierwszej części: "I cleaned the kitchen" można przetłumaczyć jako "Posprzątałem kuchnię".
#
# 4. Tłumaczenie drugiej części: "Did you at least take out the trash?" to pytanie o to, czy druga osoba wykonała jakiekolwiek zadanie domowe. Można to przetłumaczyć jako "Czy przynajmniej wyniosłeś śmieci?"
#
# 5. Połączenie obu części: Łącząc te dwa elementy, otrzymujemy pełne tłumaczenie.
#
# Tłumaczenie końcowe:
# "Posprzątałem kuchnię, czy przynajmniej wyniosłeś śmieci?"
#
# To tłumaczenie oddaje zarówno treść oryginalnej wypowiedzi, jak i jej nieformalny charakter oraz potencjalny lekki ton oskarżycielski.
# ======================
# Przeczytałam całą książkę, czy skończyłeś swoją?
# Rozumowanie krok po kroku:
#
# 1. Analiza kontekstu: Kobieta wypowiada się do mężczyzny, co sugeruje ton formalny lub przyjazny, ale nie intymny.
#
# 2. Znaczenie słów:
#    - I read = Przeczytałam
#    - the whole book = całą książkę
#    - did you finish reading yours? = czy skończyłeś czytać swoją?
#
# 3. Tłumaczenie dosłowne: "Przeczytałam całą książkę, czy skończyłeś czytać swoją?"
#
# 4. Dostosowanie do kontekstu: W języku polskim często używa się formy grzecznościowej "pan" między osobami, które nie są bliskimi znajomymi. Dodatkowo, pytanie o to, czy ktoś skończył czytać, może być wyrażone bardziej uprzejmie.
#
# 5. Ostateczne tłumaczenie: "Przeczytałam całą książkę, panie [nazwisko]. Czy pan również skończył czytać swoją?"
#
# To tłumaczenie uwzględnia kontekst dialogu między kobietą a mężczyzną i oddaje ton oraz znaczenie oryginalnej wypowiedzi.
# ======================

# %%
prompt3 = """
Oto wypowiedź pewnej osoby: '{en_text}'
Oto kontekst wypowiedzi: wypowiedź jest częscią dialogu. Wypowiada je {speaker_gender} w stronę {listener_gender}.

Przetłumacz na polski podaną wypowiedź zgodnie z podanym kontekstem. Napisz krok po kroku rozumowanie, a na końcu napisz tłumaczenie końcowe.
"""

# %%
sample = dataset.sample(20)

for index, row in sample.iterrows():
    speaker_gender = row['speaker_gender']
    listener_gender = "mężczyzny" if row['listener_gender'] == "mężczyzna" else "kobiety"
    en_text = row['en_text']

    prompt_filled = prompt3.format(en_text=row['en_text'], speaker_gender=speaker_gender, listener_gender=listener_gender)

    result = llm.prompt_chat_custom_temperature(prompt=prompt_filled, temperature=0.0)
    sample.at[index, 'prompt3'] = result

# %%
for index, row in sample.iterrows():
    print(row['pl_text'])
    print(row['prompt3'])
    print("======================")
# Out:
# W końcu naprawiłam prysznic, więc teraz już nie możesz narzekać!
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "finally" (wreszcie)
#    - "fixed" (naprawiłam/naprawiono)
#    - "shower" (prysznic)
#    - "can't complain anymore" (już nie możesz narzekać)
#
# 2. Kontekst dialogowy:
#    - Kobieta do mężczyzny
#    - Prawdopodobnie odpowiedź na wcześniejsze uwagi lub skargi dotyczące prysznica
#
# 3. Interpretacja znaczenia:
#    - Kobieta informuje mężczyznę, że naprawiła prysznic
#    - Sugeruje, że mężczyzna wcześniej narzekał na problem z prysznicem
#    - Wyraża satysfakcję i zadowolenie z faktu, że problem został rozwiązany
#
# 4. Tłumaczenie na język polski:
#    "Wreszcie naprawiłam prysznic, więc teraz już nie możesz się na to skarżyć!"
#
# To tłumaczenie oddaje sens oryginalnej wypowiedzi, uwzględniając kontekst dialogowy między kobietą a mężczyzną oraz emocjonalne zabarwienie komunikatu.
# ======================
# Naprawiłam samochód, czy udało ci się naprawić rower?
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Mamy do czynienia z dialogiem między dwiema kobietami. Jedna z nich mówi o naprawie samochodu, a następnie pyta drugą o naprawę roweru.
#
# 2. Kontekst gramatyczny: Zdanie "I fixed the car, did you manage to fix your bike?" zawiera dwa elementy:
#    - Pierwsza część zdania: "I fixed the car" (Ja naprawiłam samochód)
#    - Druga część zdania: "did you manage to fix your bike?" (Czy udało ci się naprawić twój rower?)
#
# 3. Tłumaczenie pierwszej części zdania: "I fixed the car" można przetłumaczyć jako "Naprawiłam samochód".
#
# 4. Tłumaczenie drugiej części zdania: "Did you manage to fix your bike?" to pytanie o to, czy druga osoba poradziła sobie z naprawą swojego roweru. Można to przetłumaczyć jako "Czy udało ci się naprawić swój rower?" lub "Jak poszła naprawa twojego roweru?"
#
# 5. Połączenie obu części: Łącząc te dwa tłumaczenia, otrzymujemy:
#    "Naprawiłam samochód, czy udało ci się naprawić swój rower?"
#
# Tłumaczenie końcowe:
# "Naprawiłam samochód, czy udało ci się naprawić swój rower?"
#
# To tłumaczenie oddaje sens oryginalnego zdania i pasuje do kontekstu dialogu między dwiema kobietami.
# ======================
# Znalazłam klucze, czy znalazłaś swój portfel?
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Mamy do czynienia z dialogiem między dwiema kobietami. Jedna z nich mówi, że znalazła klucze, a następnie pyta drugą o jej portfel.
#
# 2. Kontekst emocjonalny: Ponieważ są to kobiety i prawdopodobnie znają się, możemy przypuszczać, że ton wypowiedzi jest przyjazny lub neutralny.
#
# 3. Znaczenie poszczególnych elementów:
#    - "I found the keys" = Znalazłam klucze
#    - "did you find your wallet?" = Czy znalazłaś swój portfel?
#
# 4. Tłumaczenie dosłowne:
#    - Znalazłam klucze, czy znalazłaś swój portfel?
#
# 5. Dostosowanie do polskiego stylu komunikacji:
#    - W języku polskim często używa się formy grzecznościowej "pani", szczególnie gdy mówimy do nieznajomej osoby tej samej płci.
#    - Możemy dodać lekki akcent przyjazny, aby oddać ton oryginalnej wypowiedzi.
#
# Tłumaczenie końcowe:
# "Znalazłam klucze, proszę pani, czy może pani znalazła swój portfel?"
#
# To tłumaczenie uwzględnia kontekst dialogu między kobietami oraz przyjazny ton wypowiedzi.
# ======================
# Posprzątałem kuchnię, wyniosłeś chociaż śmieci?
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Mamy do czynienia z dialogiem między dwoma mężczyznami.
# 2. Kontekst emocjonalny: Wypowiedź sugeruje lekki ton pretensji lub irytacji ze strony mówiącego.
# 3. Znaczenie poszczególnych elementów:
#    - "I cleaned the kitchen" = Posprzątałem kuchnię
#    - "did you at least take out the trash?" = Czy przynajmniej wyniosłeś śmieci?
# 4. Tłumaczenie dosłowne:
#    "Posprzątałem kuchnię, czy przynajmniej wyniosłeś śmieci?"
# 5. Dostosowanie do kontekstu i stylu mowy:
#    - Użycie bardziej potocznego języka
#    - Dodanie nuty pretensji/irytacji
#
# Tłumaczenie końcowe:
# "Sprzątnąłem kuchnię, a ty chociaż wyniosłeś śmieci?" (z lekkim naciskiem na ostatnie słowa)
# ======================
# Myślałam, że umówiliśmy się na wspólne sprzątanie, więc czemu wszystko robię sama?
# Rozumowanie krok po kroku:
#
# 1. Analiza kontekstu: Wypowiedź jest częścią dialogu między kobietą a mężczyzną. Kobieta wyraża swoje niezadowolenie i zdziwienie faktem, że musi sprzątać sama, mimo wcześniejszej umowy o wspólnym sprzątaniu.
#
# 2. Identyfikacja kluczowych elementów:
#    - "I thought" - myślała, sądziła
#    - "we agreed" - uzgodniliśmy, umówiliśmy się
#    - "to clean the house together today" - żeby posprzątać dom razem dzisiaj
#    - "so why" - więc dlaczego
#    - "am I doing everything alone?" - robię wszystko sam?
#
# 3. Tłumaczenie dosłowne:
#    "Myślałam, że uzgodniliśmy, że posprzątamy dom razem dzisiaj, więc dlaczego robię wszystko sam?"
#
# 4. Dostosowanie do naturalnego brzmienia języka polskiego:
#    "Myślałam, że umówiliśmy się na sprzątanie domu razem dzisiaj, więc dlaczego ja robię wszystko sama?"
#
# 5. Ostateczne tłumaczenie:
#    "Myślałam, że umówiliśmy się na sprzątanie domu razem dzisiaj, więc dlaczego ja robię wszystko sama?"
#
# To tłumaczenie oddaje sens oryginalnej wypowiedzi, uwzględniając kontekst dialogu między kobietą a mężczyzną oraz emocjonalny ton wypowiedzi.
# ======================
# Znalazłem klucze, czy znalazłaś swój portfel?
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Mamy do czynienia z dialogiem między dwoma osobami - mężczyzną i kobietą.
#
# 2. Znaczenie poszczególnych elementów zdania:
#    - "I found" oznacza "Znalazłem"
#    - "the keys" oznacza "klucze"
#    - "did you find" to pytanie o znalezienie czegoś przez drugą osobę, czyli "Czy ty znalazłaś?"
#    - "your wallet" oznacza "twoją portmonetkę"
#
# 3. Kontekst płciowy: Ponieważ wypowiedź jest skierowana do kobiety przez mężczyznę, użyjemy formy żeńskiej dla drugiej osoby liczby pojedynczej.
#
# 4. Tłumaczenie dosłowne: "Znalazłem klucze, czy ty znalazłaś twoją portmonetkę?"
#
# 5. Uproszczenie i dostosowanie do naturalnego języka polskiego:
#    - Usunięcie zaimka dzierżawczego "twoją" przed "portmonetkę", ponieważ w języku polskim nie jest on potrzebny w takim kontekście.
#    - Zastąpienie "keys" bardziej naturalnym określeniem "klucze".
#
# Tłumaczenie końcowe:
# "Znalazłem klucze, czy znalazłaś portmonetkę?"
#
# To tłumaczenie oddaje sens oryginalnej wypowiedzi, uwzględniając kontekst dialogu między mężczyzną a kobietą oraz naturalność języka polskiego.
# ======================
# Kupiłem wszystko na przyjęcie i udekorowałem pokój, czy udało ci się zaprosić wszystkich naszych przyjaciół?
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Mamy do czynienia z dialogiem między dwoma mężczyznami. Jeden z nich (nazwijmy go A) pyta drugiego (nazwijmy go B), czy udało mu się zaprosić wszystkich przyjaciół na imprezę.
#
# 2. Zrozumienie treści: A chce się dowiedzieć, czy B zaprosił wszystkich znajomych na imprezę. Jednocześnie informuje, że on sam zajmował się zakupami i dekoracją.
#
# 3. Tłumaczenie poszczególnych elementów:
#    - "I bought everything for the party" = Kupiłem wszystko na imprezę
#    - "and decorated the room" = i ozdobiłem pokój
#    - "were you able to invite all our friends?" = Czy udało ci się zaprosić wszystkich naszych przyjaciół?
#
# 4. Uwzględnienie kontekstu: Ponieważ jest to dialog między mężczyznami, możemy użyć bardziej potocznego języka i formy grzecznościowej "ty".
#
# 5. Łączenie elementów:
#    - Kupiłem wszystko na imprezę i ozdobiłem pokój, czy udało ci się zaprosić wszystkich naszych przyjaciół?
#
# Tłumaczenie końcowe:
# "Kupiłem wszystko na imprezę i ozdobiłem pokój, czy udało ci się zaprosić wszystkich naszych przyjaciół?"
# ======================
# W końcu naprawiłem prysznic, więc teraz już nie możesz narzekać!
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "finally" (wreszcie)
#    - "fixed" (naprawiłem)
#    - "shower" (prysznic)
#    - "can't complain anymore" (już nie możesz narzekać)
#
# 2. Kontekst dialogu między dwoma mężczyznami:
#    - Sugeruje to, że temat dotyczy czegoś wspólnego lub problematycznego dla obu stron.
#
# 3. Zrozumienie znaczenia całej wypowiedzi:
#    - Mężczyzna informuje drugiego mężczyznę, że udało mu się naprawić prysznic.
#    - Wyraża satysfakcję i chce zakończyć ewentualne narzekania drugiej osoby na ten temat.
#
# 4. Tłumaczenie na język polski:
#    "Wreszcie naprawiłem prysznic, więc teraz już nie masz powodu do narzekania!"
#
# To tłumaczenie oddaje sens oryginalnej wypowiedzi, uwzględniając kontekst dialogu między dwoma mężczyznami oraz intencje mówiącego.
# ======================
# Naprawiłem samochód, czy udało ci się naprawić rower?
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Mamy do czynienia z dialogiem między dwoma osobami - mężczyzną i kobietą.
#
# 2. Identyfikacja podmiotów:
#    - "I" - mężczyzna
#    - "you" - kobieta
#
# 3. Rozpoznanie czasownika:
#    - "fixed" - czas przeszły od "fix" (naprawić)
#
# 4. Określenie przedmiotów:
#    - "car" - samochód
#    - "your bike" - twój rower
#
# 5. Struktura zdania: Pytanie retoryczne lub stwierdzenie z pytaniem na końcu.
#
# 6. Kontekst emocjonalny: Możliwe, że mężczyzna chce się dowiedzieć, czy kobieta również poradziła sobie z problemem technicznym.
#
# 7. Tłumaczenie dosłowne:
#    - Ja naprawiłem samochód, czy udało ci się naprawić swój rower?
#
# 8. Tłumaczenie uwzględniające kontekst:
#    - Naprawiłem samochód. A jak tam twój rower? Udało ci się go naprawić?
#
# Tłumaczenie końcowe:
# Naprawiłem samochód. A jak tam twój rower? Udało ci się go naprawić?
# ======================
# Skończyłem raport, czy ukończyłaś prezentację?
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Mamy do czynienia z dialogiem między dwoma osobami - mężczyzną i kobietą.
#
# 2. Identyfikacja mówcy: Wypowiedź "I finished the report, did you complete the presentation?" pochodzi od mężczyzny.
#
# 3. Znaczenie poszczególnych elementów:
#    - "I finished the report" oznacza, że mężczyzna ukończył raport.
#    - "did you complete the presentation?" to pytanie skierowane do kobiety, czy ona ukończyła prezentację.
#
# 4. Kontekst gramatyczny: Pytanie jest sformułowane w czasie przeszłym i ma charakter pytający.
#
# 5. Tłumaczenie dosłowne: "Ukończyłem raport, czy ty ukończyłaś prezentację?"
#
# 6. Dostosowanie do naturalnego języka polskiego:
#    - Użyjemy bardziej naturalnego zwrotu "Czy ty też..." zamiast "czy ty ukończyłaś".
#    - Dodamy znak zapytania na końcu zdania, aby zaznaczyć, że jest to pytanie.
#
# Tłumaczenie końcowe:
# "Ukończyłem raport. Czy ty też skończyłaś prezentację?"
# ======================
# Siedziałam całą noc przygotowując prezentację, bo obiecałeś, że mi pomożesz — dlaczego się nie pojawiłeś?
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Kobieta zwraca się do mężczyzny, prawdopodobnie w tonie pretensjonalnym lub rozczarowanym.
# 2. Znaczenie poszczególnych elementów:
#    - "I stayed up all night" - spędziła całą noc na przygotowaniach
#    - "preparing the presentation" - przygotowywała prezentację
#    - "because you promised to help me" - ponieważ on obiecał jej pomóc
#    - "why didn't you show up?" - dlaczego nie przyszedłeś?
# 3. Kontekst emocjonalny: Rozczarowanie i frustracja ze strony kobiety
# 4. Tłumaczenie dosłowne:
#    "Spędziłam całą noc na przygotowywaniu prezentacji, bo obiecałeś mi pomóc. Dlaczego nie przyszedłeś?"
# 5. Uwzględnienie kontekstu emocjonalnego:
#    "Poświęciłam całą noc na przygotowania do tej prezentacji, bo obiecałeś mi pomóc. A ty się nie pokazałeś! Dlaczego?"
#
# Tłumaczenie końcowe:
# "Poświęciłam całą noc na przygotowania do tej prezentacji, bo obiecałeś mi pomóc. A ty się nie pokazałeś! Dlaczego?"
# ======================
# Napisałam list, czy go wysłałeś?
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Mamy do czynienia z dialogiem między kobietą a mężczyzną.
# 2. Kontekst płciowy: Kobieta pyta mężczyznę o coś, co on powinien zrobić (wysłać list).
# 3. Czasownik "wrote": Wskazuje na to, że kobieta napisała list.
# 4. Czasownik "sent": Oczekiwany rezultat działania mężczyzny.
# 5. Struktura zdania: Pytanie zamknięte, które można odpowiedzieć "tak" lub "nie".
# 6. Ton wypowiedzi: Może być neutralny lub lekko niecierpliwy/zdenerwowany.
#
# Tłumaczenie końcowe:
#
# "Napisałam list, czy go wysłałeś?"
#
# To tłumaczenie oddaje sens oryginalnego zdania, uwzględniając kontekst dialogu między kobietą a mężczyzną oraz oczekiwane działanie ze strony mężczyzny.
# ======================
# Spędziłem cały dzień naprawiając twój laptop, a ty nawet nie powiedziałeś "dziękuję"!
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Mamy do czynienia z dialogiem między dwoma mężczyznami. Jeden z nich skarży się, że spędził cały dzień naprawiając czyjś laptop, ale nie otrzymał podziękowania.
#
# 2. Tłumaczenie poszczególnych elementów:
#    - "I spent the whole day" = Spędziłem cały dzień
#    - "fixing your laptop" = naprawiając twój laptop
#    - "and you didn't even say thank you!" = i ty nawet nie powiedziałeś dziękuję!
#
# 3. Uwzględnienie tonu wypowiedzi: Wypowiedź ma charakter pretensji lub żalu, co sugeruje użycie bardziej bezpośredniego i emocjonalnego języka niż formalne "dziękuję".
#
# 4. Kontekst społeczny: Rozmowa między mężczyznami, prawdopodobnie znajomymi lub kolegami, sugeruje użycie bardziej potocznego języka.
#
# 5. Tłumaczenie końcowe:
#
# "Słuchaj, stary, cały dzień przesiedziałem nad twoim laptopem, a ty nawet nie powiedziałeś dzięki?"
#
# To tłumaczenie oddaje sens oryginalnej wypowiedzi, uwzględniając kontekst dialogu między mężczyznami oraz emocjonalny ton pretensji.
# ======================
# Czekałem na ciebie prawie godzinę w deszczu, a ty tylko napisałeś „sorry”?
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Mamy do czynienia z dialogiem między dwoma mężczyznami. Jeden z nich czekał przez prawie godzinę na deszczu, a drugi spóźnił się i przesłał krótki tekst "sorry".
#
# 2. Tłumaczenie poszczególnych elementów:
#    - I waited for you: Czekałem na ciebie
#    - for almost an hour: prawie godzinę
#    - in the rain: na deszczu
#    - and you just texted: a ty po prostu napisałeś
#    - sorry: sorry (lub "przepraszam")
#
# 3. Uwzględnienie emocji i tonu wypowiedzi: Wypowiedź wyraża frustrację i rozgoryczenie ze strony pierwszego mężczyzny.
#
# 4. Złożenie tłumaczenia: Biorąc pod uwagę wszystkie powyższe elementy, możemy stworzyć następujące tłumaczenie:
#
# "Czekałem na ciebie prawie godzinę na deszczu, a ty po prostu napisałeś 'przepraszam'?"
#
# To tłumaczenie oddaje zarówno dosłowny sens oryginalnej wypowiedzi, jak i jej emocjonalny wydźwięk w kontekście dialogu między dwoma mężczyznami.
# ======================
# Czekałam na ciebie prawie godzinę w deszczu, a ty tylko napisałaś „sorry”?
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Mamy do czynienia z dialogiem między dwiema kobietami. Jedna z nich czekała przez prawie godzinę w deszczu na drugą.
#
# 2. Interpretacja emocji: Sformułowanie "waited for you for almost an hour in the rain" sugeruje frustrację i niezadowolenie ze strony mówiącej.
#
# 3. Kontekst komunikacyjny: Druga kobieta odpowiedziała krótkim "sorry", co może być postrzegane jako niewystarczające lub lekceważące w tej sytuacji.
#
# 4. Tłumaczenie dosłowne: "Czekałam na ciebie prawie godzinę w deszczu, a ty wysłałaś tylko 'przepraszam'?"
#
# 5. Dostosowanie do kontekstu: Biorąc pod uwagę emocje i ton wypowiedzi, oraz fakt, że jest to dialog między kobietami, możemy dodać bardziej bezpośredni i emocjonalny ton.
#
# Tłumaczenie końcowe:
# "Czekałam na ciebie prawie godzinę w tym cholernym deszczu, a ty masz tylko tyle do powiedzenia?!"
# ======================
# Posprzątałam kuchnię, wyniosłaś chociaż śmieci?
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Mamy do czynienia z dialogiem między dwiema kobietami. Jedna z nich wykonała jakieś prace domowe (sprzątanie kuchni), a teraz pyta drugą, czy ta przynajmniej wykonała inne zadanie (wyrzucenie śmieci).
#
# 2. Kontekst emocjonalny: Ton wypowiedzi sugeruje lekkie zirytowanie lub frustrację ze strony mówiącej. Może to być spowodowane tym, że druga osoba nie wykonała swojej części obowiązków domowych.
#
# 3. Tłumaczenie dosłowne: "Posprzątałam kuchnię, czy chociaż wyniosłaś śmieci?"
#
# 4. Dostosowanie do kontekstu: Aby oddać ton i intencję oryginalnej wypowiedzi, musimy dodać nieco emocji i odniesienie do wspólnych obowiązków domowych.
#
# Tłumaczenie końcowe:
# "Posprzątałam kuchnię, czy ty chociaż wyniosłaś śmieci? Przecież umówiłyśmy się, że dzielimy się obowiązkami!"
# ======================
# Napisałam list, czy go wysłałaś?
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Mamy do czynienia z dialogiem między dwiema kobietami.
# 2. Kontekst gramatyczny: Zdanie zawiera czasownik "wrote" (napisałam) i "did you send" (czy wysłałaś?).
# 3. Kontekst społeczny: Kobieta pyta drugą kobietę o coś, co zostało przez nią wykonane.
# 4. Struktura zdania: Pytanie składa się z dwóch części - stwierdzenia faktu ("Napisałam list") i pytania ("Czy go wysłałaś?").
# 5. Tłumaczenie dosłowne: "Napisałam list, czy go wysłałaś?"
# 6. Dostosowanie do kontekstu: W języku polskim często używa się formy grzecznościowej "pani" lub "proszę pani", gdy zwracamy się do starszej osoby lub osoby, której nie znamy dobrze.
# 7. Uwzględnienie tonu wypowiedzi: Pytanie brzmi raczej jako prośba o potwierdzenie niż jako polecenie.
#
# Tłumaczenie końcowe:
# "Proszę pani, napisałam ten list. Czy mogła pani go wysłać?"
#
# To tłumaczenie uwzględnia wszystkie aspekty oryginalnego zdania oraz kontekstu dialogu między dwiema kobietami.
# ======================
# Naprawiłem samochód, czy udało ci się naprawić rower?
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Mamy do czynienia z dialogiem między dwoma mężczyznami.
# 2. Znaczenie poszczególnych elementów zdania:
#    - "I fixed the car" = Naprawiłem samochód
#    - "did you manage to fix your bike?" = Czy udało ci się naprawić twój rower?
# 3. Kontekst płciowy: Pytanie jest skierowane od mężczyzny do mężczyzny.
# 4. Użycie czasownika "manage": Sugeruje, że naprawa mogła być trudna lub problematyczna.
# 5. Struktura pytania: Jest to pytanie o charakterze przyjaznym i nieformalnym.
#
# Tłumaczenie końcowe:
#
# "Naprawiłem samochód, czy udało ci się naprawić swój rower?"
#
# To tłumaczenie oddaje znaczenie oryginalnego zdania, uwzględniając kontekst dialogu między mężczyznami oraz nieformalny ton wypowiedzi.
# ======================
# Siedziałam całą noc pomagając ci z projektem, a teraz nawet tego nie pamiętasz?
# Rozumowanie krok po kroku:
#
# 1. Analiza sytuacji: Kobieta wypowiada się do mężczyzny, prawdopodobnie w kontekście wspólnego projektu lub pracy.
# 2. Kontekst emocjonalny: Wypowiedź ma charakter oskarżycielski i wyraża rozczarowanie.
# 3. Znaczenie poszczególnych elementów:
#    - "I stayed up all night" = "Nie spałam całą noc"
#    - "helping you with your project" = "pomagając ci przy twoim projekcie"
#    - "and now you don't even remember it?" = "i teraz nawet nie pamiętasz tego?"
# 4. Tłumaczenie dosłowne:
#    "Nie spałam całą noc pomagając ci przy twoim projekcie, i teraz nawet nie pamiętasz tego?"
# 5. Dostosowanie do naturalnego języka polskiego:
#    "Nie spałam całą noc, żeby ci pomóc z tym projektem, a ty nawet tego nie pamiętasz?"
#
# Tłumaczenie końcowe:
# "Nie spałam całą noc, żeby ci pomóc z tym projektem, a ty nawet tego nie pamiętasz?"
# ======================
# Myślałam, że umówiliśmy się na wspólne sprzątanie, więc czemu wszystko robię sama?
# Rozumowanie krok po kroku:
#
# 1. Analiza kontekstu: Wypowiedź jest częścią dialogu między dwiema kobietami.
# 2. Znaczenie słów: "I thought" - Myślałam; "we agreed" - że się umówiliśmy; "to clean the house" - żeby posprzątać dom; "today" - dzisiaj; "so why" - więc dlaczego; "am I doing everything alone?" - robię wszystko sam?
# 3. Kontekst emocjonalny: Osoba wyraża zdziwienie i lekkie rozczarowanie.
# 4. Tłumaczenie dosłowne: "Myślałam, że się umówiliśmy na sprzątanie domu dzisiaj, więc dlaczego robię wszystko sam?"
# 5. Dostosowanie do języka polskiego: W języku polskim często używa się formy grzecznościowej "my", nawet gdy mowa o wspólnych planach.
# 6. Ostateczna forma: "Myślałam, że umówiliśmy się na sprzątanie domu dzisiaj, więc dlaczego ja to robię sama?"
#
# Tłumaczenie końcowe:
# "Myślałam, że umówiliśmy się na sprzątanie domu dzisiaj, więc dlaczego ja to robię sama?"
# ======================

# %%
prompt4 = """
Oto wypowiedź pewnej osoby: '{en_text}'
Oto kontekst wypowiedzi: wypowiedź jest częścią dialogu. Wypowiada je {speaker_gender} w stronę {listener_gender}.

Przetłumacz na polski podaną wypowiedź zgodnie z podanym kontekstem. Napisz krok po kroku rozumowanie, a na końcu napisz tłumaczenie końcowe.
Staraj się jak najdosłowniej przetłumaczyć wejściową wypowiedź.
"""

# %%
for index, row in sample.iterrows():
    speaker_gender = row['speaker_gender']
    listener_gender = "mężczyzny" if row['listener_gender'] == "mężczyzna" else "kobiety"
    en_text = row['en_text']

    prompt_filled = prompt4.format(en_text=row['en_text'], speaker_gender=speaker_gender, listener_gender=listener_gender)

    result = llm.prompt_chat_custom_temperature(prompt=prompt_filled, temperature=0.0)
    sample.at[index, 'prompt4'] = result

# %%
for index, row in sample.iterrows():
    print(row['pl_text'])
    print(row['prompt4'])
    print("======================")
# Out:
# W końcu naprawiłam prysznic, więc teraz już nie możesz narzekać!
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "finally" (wreszcie)
#    - "fixed" (naprawiłem/naprawiła)
#    - "shower" (prysznic)
#    - "can't complain anymore" (już nie możesz narzekać)
#
# 2. Kontekst dialogowy:
#    - Kobieta do mężczyzny
#    - Prawdopodobnie odpowiedź na wcześniejsze uwagi lub skargi dotyczące prysznica
#
# 3. Tłumaczenie dosłowne:
#    - "Wreszcie naprawiłam prysznic, więc teraz już nie możesz narzekać!"
#
# 4. Uwzględnienie tonu i intencji:
#    - Ton może być lekko ironiczny lub triumfalny
#    - Intencja to prawdopodobnie zamknięcie tematu poprzedniej dyskusji
#
# 5. Dostosowanie do naturalnego języka polskiego:
#    - "Wreszcie udało mi się naprawić prysznic, więc teraz już nie masz powodu do narzekania!"
#
# Tłumaczenie końcowe:
# "Wreszcie udało mi się naprawić prysznic, więc teraz już nie masz powodu do narzekania!"
# ======================
# Naprawiłam samochód, czy udało ci się naprawić rower?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "fixed" (naprawiłem/naprawiła)
#    - "car" (samochód)
#    - "did you manage" (udało ci się)
#    - "bike" (rower)
#
# 2. Kontekst płciowy:
#    - Wypowiedź jest skierowana od kobiety do kobiety.
#
# 3. Czas gramatyczny:
#    - Użycie czasu przeszłego ("fixed") sugeruje, że mowa o czynnościach wykonanych wcześniej.
#
# 4. Struktura zdania:
#    - Zdanie ma formę pytającą, ale zawiera informację o tym, co samemu udało się zrobić.
#
# 5. Tłumaczenie dosłowne:
#    - "Naprawiłam samochód, czy udało ci się naprawić rower?"
#
# 6. Dostosowanie do kontekstu:
#    - Biorąc pod uwagę, że wypowiedź jest skierowana od kobiety do kobiety i ma charakter przyjaznego dialogu, możemy dodać nieco bardziej naturalne brzmienie.
#
# Tłumaczenie końcowe:
# "Udało mi się naprawić samochód, a Tobie jak poszło z rowerem?"
# ======================
# Znalazłam klucze, czy znalazłaś swój portfel?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "found" oznacza "znaleźć"
#    - "keys" to "klucze"
#    - "find" oznacza "znaleźć"
#    - "wallet" to "portfel"
#
# 2. Kontekst dialogowy:
#    - Wypowiedź jest częścią rozmowy między dwiema kobietami
#    - Jedna kobieta informuje drugą o znalezieniu czegoś
#
# 3. Struktura zdania:
#    - Zdanie składa się z dwóch części:
#      a) Informacja o znalezieniu przez mówiącą (ja znalazłam klucze)
#      b) Pytanie do adresatki (czy ty znalazłaś swój portfel?)
#
# 4. Tłumaczenie dosłowne:
#    - "Znalazłam klucze, czy ty znalazłaś swój portfel?"
#
# 5. Uwzględnienie kontekstu i stylu:
#    - W języku polskim pytanie o znalezienie czegoś przez inną osobę często brzmi: "Czy ty też coś znalazłaś?"
#
# Tłumaczenie końcowe:
# "Znalazłam klucze, czy ty też coś znalazłaś?"
#
# To tłumaczenie oddaje sens oryginalnej wypowiedzi, uwzględniając kontekst dialogowy i naturalny sposób wyrażenia takiego pytania w języku polskim.
# ======================
# Posprzątałem kuchnię, wyniosłeś chociaż śmieci?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "cleaned" (sprzątnąłem)
#    - "kitchen" (kuchnia)
#    - "did you" (czy ty)
#    - "take out" (wyjąć)
#    - "trash" (śmieci)
#
# 2. Kontekst dialogowy:
#    - Mężczyzna do mężczyzny
#    - Pytanie retoryczne lub stwierdzenie z prośbą
#
# 3. Tłumaczenie dosłowne:
#    "Sprzątnąłem kuchnię, czy chociaż wyjąłeś śmieci?"
#
# 4. Uwagi o tonie i intencji:
#    - Ton może być lekko zirytowany lub zabawny
#    - Intencja to prawdopodobnie delikatne przypomnienie o obowiązkach domowych
#
# 5. Dostosowanie do naturalnego języka polskiego:
#    - Zamiana "chociaż" na bardziej naturalne "czy nie"
#
# Tłumaczenie końcowe:
# "Sprzątnąłem kuchnię, czy nie mógłbyś chociaż wyjąć śmieci?"
# ======================
# Myślałam, że umówiliśmy się na wspólne sprzątanie, więc czemu wszystko robię sama?
# Rozumowanie krok po kroku:
#
# 1. Analiza oryginalnej wypowiedzi: "I thought we agreed to clean the house together today, so why am I doing everything alone?"
#    - Podmiot: "I" (ja)
#    - Czasownik: "thought" (myślałam/myślałem), "doing" (robię)
#    - Przymiotnik: "alone" (sam/sama)
#    - Kontekst: Rozmowa między dwiema osobami, prawdopodobnie partnerami
#
# 2. Tłumaczenie poszczególnych elementów:
#    - "I thought": Myślałam/Myślałem
#    - "we agreed": że się umówiliśmy
#    - "to clean the house": żeby sprzątać dom
#    - "together": razem
#    - "today": dzisiaj
#    - "so why": więc dlaczego
#    - "am I doing everything": robię wszystko
#    - "alone": sam/sama
#
# 3. Budowanie zdania w języku polskim:
#    - "Myślałam, że się umówiliśmy dzisiaj na sprzątanie domu razem, więc dlaczego robię wszystko sama?"
#
# 4. Dostosowanie do kontekstu (kobieta do mężczyzny):
#    - "Myślałam, że się umówiliśmy dzisiaj na sprzątanie domu razem, więc dlaczego robię wszystko sama, skoro miałeś mi pomagać?"
#
# Tłumaczenie końcowe:
# "Myślałam, że się umówiliśmy dzisiaj na sprzątanie domu razem, więc dlaczego robię wszystko sama, skoro miałeś mi pomagać?"
# ======================
# Znalazłem klucze, czy znalazłaś swój portfel?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "found" oznacza "znaleźć"
#    - "keys" to "klucze"
#    - "find" oznacza "znaleźć"
#    - "wallet" to "portfel"
#
# 2. Kontekst dialogowy:
#    - Mężczyzna wypowiada te słowa do kobiety
#    - Pytanie sugeruje, że oboje szukali czegoś zagubionego
#
# 3. Struktura zdania:
#    - Zdanie składa się z dwóch części: stwierdzenia i pytania
#
# 4. Tłumaczenie dosłowne:
#    - "Znalazłem klucze, czy ty znalazłaś swój portfel?"
#
# 5. Uwzględnienie kontekstu:
#    - Mężczyzna informuje kobietę o znalezieniu swoich kluczy
#    - Pyta ją, czy ona również odnalazła swój portfel
#
# 6. Dostosowanie do naturalnego brzmienia w języku polskim:
#    - Dodanie formy grzecznościowej "pani" dla kobiety
#
# Tłumaczenie końcowe:
# "Znalazłem klucze, pani. Czy udało się pani znaleźć portfel?"
# ======================
# Kupiłem wszystko na przyjęcie i udekorowałem pokój, czy udało ci się zaprosić wszystkich naszych przyjaciół?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych i ich znaczenia:
#    - "bought": kupiłem
#    - "everything": wszystko
#    - "for the party": na imprezę
#    - "decorated": udekorowałem
#    - "room": pokój
#    - "were you able": czy byłeś w stanie
#    - "invite": zaprosić
#    - "all our friends": wszystkich naszych przyjaciół
#
# 2. Uwzględnienie kontekstu dialogowego:
#    - Mężczyzna do mężczyzny
#    - Pytanie o wynik działania drugiej osoby
#
# 3. Tłumaczenie dosłowne:
#    "Kupiłem wszystko na imprezę i udekorowałem pokój, czy byłeś w stanie zaprosić wszystkich naszych przyjaciół?"
#
# 4. Dostosowanie do naturalnego brzmienia języka polskiego:
#    "Zrobiłem zakupy i udekorowałem pokój na imprezę, czy udało ci się zaprosić wszystkich naszych znajomych?"
#
# Tłumaczenie końcowe:
# "Zrobiłem zakupy i udekorowałem pokój na imprezę, czy udało ci się zaprosić wszystkich naszych znajomych?"
# ======================
# W końcu naprawiłem prysznic, więc teraz już nie możesz narzekać!
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "finally" = ostatecznie, wreszcie
#    - "fixed" = naprawiłem
#    - "shower" = prysznic
#    - "can't complain anymore" = nie możesz już narzekać
#
# 2. Kontekst dialogowy i relacja między rozmówcami:
#    - Mężczyzna do mężczyzny
#    - Prawdopodobnie istniał jakiś problem z prysznicem, który został teraz naprawiony
#
# 3. Interpretacja znaczenia całej wypowiedzi:
#    - Osoba mówiąca informuje drugą osobę, że naprawiła prysznic
#    - Sugeruje, że druga osoba mogła narzekać na ten problem
#    - Wyraża satysfakcję z faktu, że problem został rozwiązany
#
# 4. Tłumaczenie dosłowne:
#    "Wreszcie naprawiłem prysznic, więc teraz nie możesz już narzekać!"
#
# 5. Tłumaczenie końcowe (bardziej naturalne):
#    "Wreszcie naprawiłem prysznic, więc teraz nie masz powodu do narzekania."
#
# To tłumaczenie oddaje sens oryginalnej wypowiedzi, jednocześnie brzmiąc bardziej naturalnie w języku polskim w kontekście dialogu między dwoma mężczyznami.
# ======================
# Naprawiłem samochód, czy udało ci się naprawić rower?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "fixed" (naprawiłem)
#    - "car" (samochód)
#    - "managed" (udało się)
#    - "bike" (rower)
#
# 2. Kontekst dialogowy:
#    - Mężczyzna do kobiety
#    - Pytanie o czyjąś czynność
#
# 3. Struktura zdania:
#    - Zdanie pytające
#    - Odpowiednik polskiego "Czy udało ci się...?"
#
# 4. Tłumaczenie dosłowne:
#    - "Naprawiłem samochód, czy udało ci się naprawić rower?"
#
# 5. Uproszczenie i dostosowanie do naturalnego języka polskiego:
#    - "Naprawiłem samochód, a ty naprawiłaś swój rower?"
#
# Tłumaczenie końcowe:
# "Naprawiłem samochód, a ty naprawiłaś swój rower?"
# ======================
# Skończyłem raport, czy ukończyłaś prezentację?
# Rozumowanie krok po kroku:
#
# 1. Analiza struktury zdania:
#    - "I finished the report" - czas przeszły dokonany (Past Simple)
#    - "did you complete the presentation?" - pytanie o czynność wykonaną przez drugą osobę
#
# 2. Kontekst dialogowy:
#    - Mężczyzna zwraca się do kobiety
#    - Pytanie dotyczy ukończenia pracy przez kobietę
#
# 3. Tłumaczenie dosłowne:
#    - "I finished the report" -> "Skończyłem raport"
#    - "did you complete the presentation?" -> "Czy ty skończyłaś prezentację?"
#
# 4. Uwzględnienie kontekstu i stylu wypowiedzi:
#    - Mężczyzna pyta kobietę o jej postęp w pracy
#    - Użycie formy grzecznościowej "Czy" na początku pytania
#
# 5. Ostateczne tłumaczenie:
#    - "Skończyłem raport. Czy ty skończyłaś prezentację?"
#
# To tłumaczenie oddaje dosłowne znaczenie oryginalnej wypowiedzi, uwzględniając kontekst dialogowy i formalny ton wypowiedzi między dwiema osobami.
# ======================
# Siedziałam całą noc przygotowując prezentację, bo obiecałeś, że mi pomożesz — dlaczego się nie pojawiłeś?
# Rozumowanie krok po kroku:
#
# 1. Analiza oryginalnej wypowiedzi:
#    - "I stayed up all night preparing the presentation"
#      - Osoba spędziła całą noc przygotowując prezentację
#    - "because you promised to help me"
#      - Powodem było obiecanie pomocy przez drugą osobę
#    - "why didn't you show up?"
#      - Pytanie o powód nieobecności tej osoby
#
# 2. Kontekst wypowiedzi:
#    - Kobieta wypowiada się do mężczyzny
#    - Jest wyraźnie zdenerwowana i rozczarowana
#
# 3. Tłumaczenie dosłowne:
#    - "Spędziłam całą noc przygotowując prezentację"
#    - "bo obiecałeś mi pomóc"
#    - "dlaczego się nie pojawiłeś?"
#
# 4. Uwzględnienie emocji i tonu wypowiedzi:
#    - W języku polskim często używa się bardziej bezpośrednich form pytających
#    - Można dodać elementy wyrażające frustrację i rozczarowanie
#
# 5. Ostateczne tłumaczenie:
#    - "Całą noc harowałam nad tą prezentacją!"
#    - "Bo obiecałeś mi pomóc!"
#    - "Dlaczego cię tu nie ma?!"
#
# To tłumaczenie oddaje sens oryginalnej wypowiedzi, uwzględnia kontekst dialogu oraz emocje mówiącej osoby.
# ======================
# Napisałam list, czy go wysłałeś?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów i struktury zdania:
#    - "I wrote the letter" - ja napisałam list
#    - "did you send it?" - czy ty go wysłałeś?
#
# 2. Kontekst dialogowy:
#    - Kobieta do mężczyzny
#    - Pytanie o coś, co zostało wykonane przez drugą osobę
#
# 3. Tłumaczenie dosłowne:
#    - "Ja napisałam list, czy ty go wysłałeś?"
#
# 4. Uwzględnienie naturalności języka polskiego:
#    - W języku polskim pytania często zaczynają się od czasownika
#    - Można dodać formę grzecznościową "pan" lub "proszę pana"
#
# 5. Ostateczne tłumaczenie:
#    - "Proszę pana, czy pan wysłał ten list?"
#
# To tłumaczenie oddaje sens oryginalnej wypowiedzi, uwzględniając kontekst dialogowy między kobietą a mężczyzną oraz naturalność języka polskiego.
# ======================
# Spędziłem cały dzień naprawiając twój laptop, a ty nawet nie powiedziałeś "dziękuję"!
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "spent" (spędził)
#    - "whole day" (cały dzień)
#    - "fixing" (naprawiając)
#    - "laptop" (laptop)
#    - "didn't even say" (nawet nie powiedział)
#    - "thank you" (dziękuję)
#
# 2. Kontekst dialogowy:
#    - Mężczyzna do mężczyzny
#    - Emocjonalne wyrażenie frustracji lub rozczarowania
#
# 3. Tłumaczenie dosłowne:
#    "Spędziłem cały dzień naprawiając twój laptop, i nawet nie powiedziałeś dziękuję!"
#
# 4. Uwagi o stylu i tonie:
#    - W języku polskim możemy użyć bardziej bezpośredniego i emocjonalnego tonu niż w języku angielskim.
#    - Możemy dodać bardziej potoczne zwroty, aby lepiej oddać emocje mówiącego.
#
# 5. Ostateczne tłumaczenie:
#    "Cholera, cały dzień grzebałem przy twoim kompie, a ty nawet nie powiedziałeś 'dzięki'?"
#
# To tłumaczenie uwzględnia emocjonalny charakter wypowiedzi oraz potoczny styl mówienia między mężczyznami, jednocześnie pozostając blisko oryginalnego znaczenia.
# ======================
# Czekałem na ciebie prawie godzinę w deszczu, a ty tylko napisałeś „sorry”?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - I waited: Czekałem
#    - for you: na ciebie
#    - for almost an hour: prawie godzinę
#    - in the rain: w deszczu
#    - you just texted: ty tylko napisałeś
#    - sorry: przepraszam
#
# 2. Uwzględnienie kontekstu dialogowego i relacji między rozmówcami (mężczyzna do mężczyzny):
#    - Tonacja wypowiedzi sugeruje irytację lub rozczarowanie ze strony mówiącego
#
# 3. Tłumaczenie dosłowne:
#    "Czekałem na ciebie prawie godzinę w deszczu, a ty tylko napisałeś 'przepraszam'?"
#
# 4. Dostosowanie tłumaczenia do naturalnego brzmienia języka polskiego:
#    "Czekałem na ciebie prawie godzinę w tym deszczu, a ty tylko napisałeś 'przepraszam'?"
#
# Tłumaczenie końcowe:
# "Czekałem na ciebie prawie godzinę w tym deszczu, a ty tylko napisałeś 'przepraszam'?"
# ======================
# Czekałam na ciebie prawie godzinę w deszczu, a ty tylko napisałaś „sorry”?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych i ich znaczenia:
#    - I waited: Czekałam
#    - for you: na ciebie
#    - for almost an hour: prawie godzinę
#    - in the rain: w deszczu
#    - and you just texted: a ty po prostu napisałaś
#    - sorry: przepraszam
#
# 2. Uwzględnienie kontekstu dialogowego:
#    - Wypowiedź jest skierowana do kobiety przez inną kobietę
#    - Kontekst sugeruje emocjonalne zdenerwowanie mówiącej
#
# 3. Tłumaczenie dosłowne:
#    "Czekałam na ciebie prawie godzinę w deszczu, a ty po prostu napisałaś 'przepraszam'?"
#
# 4. Dostosowanie do naturalnego brzmienia języka polskiego:
#    "Czekałam na ciebie prawie godzinę w deszczu, a ty mi teraz wysyłasz tylko 'przepraszam'?"
#
# Tłumaczenie końcowe:
# "Czekałam na ciebie prawie godzinę w deszczu, a ty mi teraz wysyłasz tylko 'przepraszam'?"
# ======================
# Posprzątałam kuchnię, wyniosłaś chociaż śmieci?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "cleaned" (sprzątnąłem)
#    - "kitchen" (kuchnia)
#    - "did you" (czy ty)
#    - "take out" (wyjąć)
#    - "trash" (śmieci)
#
# 2. Kontekst dialogowy:
#    - Kobieta do kobiety
#    - Pytanie retoryczne lub stwierdzenie z prośbą o potwierdzenie
#
# 3. Tłumaczenie dosłowne:
#    "Sprzątnęłam kuchnię, czy chociaż wyjęłaś śmieci?"
#
# 4. Uwagi dotyczące tłumaczenia:
#    - "Cleaned" może być tłumaczone jako "sprzątnęłam", co sugeruje dokładniejsze czyszczenie niż "posprzątałam".
#    - "Did you" to forma pytająca odpowiadająca polskiemu "czy ty", ale w tym kontekście lepiej brzmi "czy chociaż".
#    - "Take out" w tym kontekście oznacza "wyjąć" i odnosi się do wyniesienia śmieci do pojemnika na zewnątrz domu.
#
# 5. Tłumaczenie końcowe:
#    "Sprzątnęłam kuchnię, czy chociaż wyjęłaś śmieci?"
#
# To tłumaczenie oddaje sens oryginalnej wypowiedzi, uwzględniając kontekst dialogowy między dwiema kobietami oraz intencję mówiącej.
# ======================
# Napisałam list, czy go wysłałaś?
# Rozumowanie krok po kroku:
#
# 1. Analiza wypowiedzi: "I wrote the letter, did you send it?"
#    - Podmiot: "I" (Ja)
#    - Czasownik: "wrote" (napisałam)
#    - Przedmiot: "the letter" (list)
#    - Druga część zdania: "did you send it?" (czy go wysłałaś?)
#
# 2. Kontekst: Kobieta mówi do kobiety
#    - To sugeruje, że obie są znajomymi lub bliskimi osobami
#    - Prawdopodobnie chodzi o list napisany przez jedną z nich i prośbę o wysłanie go
#
# 3. Tłumaczenie dosłowne:
#    - "Napisałam list, czy go wysłałaś?"
#
# 4. Uwzględniając kontekst i relację między kobietami, możemy dodać bardziej naturalny ton:
#    - "Napisałam ten list, czy mogłabyś go dla mnie wysłać?"
#
# Tłumaczenie końcowe:
# "Napisałam ten list, czy mogłabyś go dla mnie wysłać?"
#
# To tłumaczenie oddaje sens oryginalnej wypowiedzi, uwzględniając kontekst dialogu między dwiema kobietami oraz prośbę o wykonanie czynności.
# ======================
# Naprawiłem samochód, czy udało ci się naprawić rower?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "fixed" (naprawiłem)
#    - "car" (samochód)
#    - "did you manage" (udało ci się)
#    - "fix" (naprawić)
#    - "bike" (rower)
#
# 2. Określenie struktury zdania:
#    Zdanie składa się z dwóch części:
#    a) Pierwsza część opisuje czynność wykonaną przez mówiącego
#    b) Druga część jest pytaniem o czynność wykonaną przez adresata
#
# 3. Tłumaczenie poszczególnych elementów:
#    - I fixed the car = Naprawiłem samochód
#    - Did you manage to fix your bike? = Czy udało ci się naprawić twój rower?
#
# 4. Połączenie elementów w całość:
#    "Naprawiłem samochód, czy udało ci się naprawić twój rower?"
#
# 5. Uwzględnienie kontekstu dialogowego:
#    Ponieważ jest to dialog między mężczyznami, możemy dodać nieformalne zwroty typowe dla takich rozmów.
#
# Tłumaczenie końcowe:
# "Naprawiłem samochód, stary, a ty jak sobie poradziłeś z rowerem?"
# ======================
# Siedziałam całą noc pomagając ci z projektem, a teraz nawet tego nie pamiętasz?
# Rozumowanie krok po kroku:
#
# 1. Analiza oryginalnego zdania:
#    - "I stayed up all night helping you with your project" - Ta część zdania opisuje czynność wykonaną przez mówiącego (kobietę) dla adresata (mężczyzny).
#    - "and now you don't even remember it?" - Ta część zdania wyraża emocje i pytanie retoryczne skierowane do adresata.
#
# 2. Tłumaczenie poszczególnych części zdania:
#    - "I stayed up all night helping you with your project" = "Nie spałam całą noc, pomagając ci przy twoim projekcie."
#    - "and now you don't even remember it?" = "i teraz nawet nie pamiętasz o tym?"
#
# 3. Połączenie obu części w jedno zdanie:
#    - "Nie spałam całą noc, pomagając ci przy twoim projekcie, i teraz nawet nie pamiętasz o tym?"
#
# 4. Uwzględnienie kontekstu dialogowego:
#    - Wypowiedź ta jest częścią dialogu między kobietą a mężczyzną.
#    - Kobieta wyraża swoje uczucia i rozczarowanie brakiem wdzięczności ze strony mężczyzny.
#
# 5. Ostateczne tłumaczenie:
#    - "Nie spałam całą noc, pomagając ci przy twoim projekcie, i teraz nawet nie pamiętasz o tym?"
#
# To tłumaczenie oddaje dosłowny sens oryginalnej wypowiedzi, uwzględniając kontekst dialogowy i emocjonalny charakter wypowiedzi.
# ======================
# Myślałam, że umówiliśmy się na wspólne sprzątanie, więc czemu wszystko robię sama?
# Rozumowanie krok po kroku:
#
# 1. Analiza oryginalnej wypowiedzi: "I thought we agreed to clean the house together today, so why am I doing everything alone?"
#    - Podmiot: ja (I)
#    - Czasownik: myślałam/myślałem (thought)
#    - Przedmiot: porozumienie dotyczące sprzątania domu razem (we agreed to clean the house together)
#    - Okoliczność czasowa: dziś (today)
#    - Pytanie retoryczne: dlaczego robię wszystko samodzielnie?
#
# 2. Kontekst: wypowiedź jest częścią dialogu między dwiema kobietami.
#
# 3. Tłumaczenie dosłowne:
#    "Myślałam, że umówiłyśmy się na wspólne sprzątanie domu dzisiaj, więc dlaczego robię wszystko sama?"
#
# 4. Uwagi o tłumaczeniu:
#    - Zachowano dosłowność oryginału
#    - Użyto formy żeńskiej ("umówiłyśmy się", "robię") zgodnie z kontekstem dialogu między kobietami
#    - Zachowano pytanie retoryczne na końcu zdania
#
# Tłumaczenie końcowe:
# "Myślałam, że umówiłyśmy się na wspólne sprzątanie domu dzisiaj, więc dlaczego robię wszystko sama?"
# ======================

# %%
prompt5 = """
Oto wypowiedź pewnej osoby: '{en_text}'
Oto kontekst wypowiedzi: wypowiedź jest częścią dialogu. Wypowiada je {speaker_gender} w stronę {listener_gender}.

Przetłumacz na polski podaną wypowiedź zgodnie z podanym kontekstem. Napisz krok po kroku rozumowanie, a na końcu napisz tłumaczenie końcowe.
Staraj się jak najdosłowniej przetłumaczyć wejściową wypowiedź.

Ostateczną wersje tłumaczenia napisz w nawiasach kwadratowych.
Oto przykład jak to zrobić:
Przykładowe zdanie po angielsku: I am a very good cook.
Przykładowe tłumaczenie: [Jestem bardzo dobrym kucharzem.]
"""

# %%
for index, row in sample.iterrows():
    speaker_gender = row['speaker_gender']
    listener_gender = "mężczyzny" if row['listener_gender'] == "mężczyzna" else "kobiety"
    en_text = row['en_text']

    prompt_filled = prompt5.format(en_text=row['en_text'], speaker_gender=speaker_gender, listener_gender=listener_gender)

    result = llm.prompt_chat_custom_temperature(prompt=prompt_filled, temperature=0.0)
    sample.at[index, 'prompt5'] = result

for index, row in sample.iterrows():
    print(row['pl_text'])
    print(row['prompt5'])
    print("======================")
# Out:
# W końcu naprawiłam prysznic, więc teraz już nie możesz narzekać!
# Rozumowanie krok po kroku:
#
# 1. "I finally" - oznacza "Wreszcie udało mi się".
# 2. "fixed the shower" - dosłownie "naprawiłam prysznic", ale w tym kontekście można to interpretować jako "naprawiłam problem z prysznicem".
# 3. "so now" - oznacza "więc teraz".
# 4. "you can't complain anymore!" - dosłownie "już nie możesz narzekać!", ale w tym kontekście sugeruje raczej "już nie masz powodu do narzekania!".
#
# Kontekst wypowiedzi: Kobieta mówi do mężczyzny, co sugeruje, że problem z prysznicem był dla niego irytujący lub denerwujący.
#
# Tłumaczenie końcowe: [Wreszcie udało mi się naprawić ten problem z prysznicem, więc już nie masz powodu do narzekania!]
#
# [Wreszcie udało mi się naprawić ten problem z prysznicem, więc już nie masz powodu do narzekania!]
# ======================
# Naprawiłam samochód, czy udało ci się naprawić rower?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "fixed" (naprawiłem/naprawiła)
#    - "car" (samochód)
#    - "did you manage" (udało ci się)
#    - "fix" (naprawić)
#    - "your bike" (twój rower)
#
# 2. Uwzględnienie kontekstu:
#    - Dialog między dwiema kobietami
#    - Temat dotyczy naprawiania pojazdów
#
# 3. Tłumaczenie dosłowne:
#    - "Naprawiłam samochód, czy udało ci się naprawić twój rower?"
#
# 4. Dostosowanie do kontekstu i stylu mowy:
#    - Dodanie formy grzecznościowej "pani" dla drugiej osoby
#    - Zastąpienie "udało ci się" bardziej naturalnym zwrotem "poradziła sobie pani"
#
# 5. Ostateczna wersja tłumaczenia:
#    [Naprawiłam samochód, czy poradziła sobie pani z naprawą roweru?]
# ======================
# Znalazłam klucze, czy znalazłaś swój portfel?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "found" (znaleźć)
#    - "keys" (klucze)
#    - "did you find" (czy znalazłaś)
#    - "your wallet" (twoja portmonetka)
#
# 2. Kontekst dialogowy:
#    - Kobieta mówi do innej kobiety
#    - Pytanie o znalezienie czegoś
#
# 3. Tłumaczenie dosłowne:
#    - "Znalazłam klucze, czy znalazłaś swoją portmonetkę?"
#
# 4. Dostosowanie do naturalnego języka polskiego:
#    - "Znalazłam klucze, czy ty znalazłaś swój portfel?"
#
# 5. Ostateczna wersja tłumaczenia:
# [Znalazłam klucze, czy ty znalazłaś swój portfel?]
# ======================
# Posprzątałem kuchnię, wyniosłeś chociaż śmieci?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "cleaned" (sprzątnąłem)
#    - "kitchen" (kuchnia)
#    - "did you" (czy ty)
#    - "take out" (wyjąć)
#    - "trash" (śmieci)
#
# 2. Ustalenie kontekstu:
#    - Mężczyzna mówi do mężczyzny
#    - Jest to część dialogu
#
# 3. Tłumaczenie poszczególnych elementów:
#    - "I cleaned the kitchen" = Sprzątnąłem kuchnię
#    - "did you at least" = czy chociaż
#    - "take out the trash" = wyjąć śmieci
#
# 4. Łączenie elementów w logiczną całość:
#    - Sprzątnąłem kuchnię, czy chociaż wyjąłeś śmieci?
#
# 5. Ostateczne tłumaczenie:
#    [Sprzątnąłem kuchnię, czy chociaż wyjąłeś śmieci?]
# ======================
# Myślałam, że umówiliśmy się na wspólne sprzątanie, więc czemu wszystko robię sama?
# Rozumowanie krok po kroku:
#
# 1. "I thought" - oznacza "Myślałam", ponieważ wypowiedź jest w czasie przeszłym i odnosi się do kobiety (forma żeńska).
# 2. "we agreed" - oznacza "że się umówiliśmy", ponieważ chodzi o wspólną decyzję między dwiema osobami.
# 3. "to clean the house" - oznacza "aby posprzątać dom", co jest czynnością wykonywaną przez oboje.
# 4. "together today" - oznacza "razem dzisiaj", wskazując na konkretny dzień i wspólne działanie.
# 5. "so why" - oznacza "więc dlaczego", wprowadzając pytanie retoryczne.
# 6. "am I doing everything alone?" - oznacza "robię wszystko sama?", wyrażając frustrację z powodu samotnego wykonywania pracy.
#
# Tłumaczenie końcowe:
# [Myślałam, że się umówiliśmy, że razem posprzątamy dom dzisiaj, więc dlaczego robię wszystko sama?]
# ======================
# Znalazłem klucze, czy znalazłaś swój portfel?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "found" oznacza "znaleźć"
#    - "keys" oznacza "klucze"
#    - "did you find" oznacza "czy ty znalazłaś" (forma pytająca)
#    - "your wallet" oznacza "twoja portmonetka"
#
# 2. Kontekst dialogowy:
#    - Mężczyzna zwraca się do kobiety
#    - Pytanie dotyczy znalezienia przedmiotu przez kobietę
#
# 3. Tłumaczenie dosłowne:
#    - "Znalazłem klucze, czy ty znalazłaś swoją portmonetkę?"
#
# 4. Uproszczenie i dostosowanie do naturalnego języka polskiego:
#    - "Znalazłem klucze, czy znalazłaś swój portfel?"
#
# Ostateczne tłumaczenie:
# [Znalazłem klucze, czy znalazłaś swój portfel?]
# ======================
# Kupiłem wszystko na przyjęcie i udekorowałem pokój, czy udało ci się zaprosić wszystkich naszych przyjaciół?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "bought" = kupiłem
#    - "everything" = wszystko
#    - "for the party" = na imprezę
#    - "decorated" = udekorowałem
#    - "room" = pokój
#    - "were you able" = czy byłeś w stanie
#    - "invite" = zaprosić
#    - "all our friends" = wszystkich naszych znajomych
#
# 2. Uwzględnienie kontekstu dialogowego i płci mówiącego:
#    - Mężczyzna mówi do mężczyzny, co sugeruje nieformalny ton i możliwe skrócenie formy grzecznościowej.
#
# 3. Złożenie zdania w języku polskim:
#    - "Kupiłem wszystko na imprezę i udekorowałem pokój, czy byłeś w stanie zaprosić wszystkich naszych znajomych?"
#
# 4. Dostosowanie do nieformalnego charakteru dialogu między mężczyznami:
#    - Możemy usunąć "byłeś w stanie", ponieważ w takim kontekście brzmi to formalnie i nie pasuje do dialogu między kolegami.
#
# 5. Ostateczne tłumaczenie:
#    [Kupiłem wszystko na imprezę i udekorowałem pokój, udało ci się zaprosić wszystkich naszych znajomych?]
# ======================
# W końcu naprawiłem prysznic, więc teraz już nie możesz narzekać!
# Rozumowanie krok po kroku:
#
# 1. "I finally" - oznacza "Wreszcie udało mi się".
# 2. "fixed the shower" - dosłownie "naprawiłem prysznic", ale w tym kontekście może też oznaczać "skończyłem naprawiać prysznic".
# 3. "so now" - oznacza "więc teraz".
# 4. "you can't complain anymore!" - dosłownie "już nie możesz narzekać!", ale w tym kontekście sugeruje raczej "teraz już nie masz powodu do narzekania".
# 5. Kontekst dialogu między dwoma mężczyznami sugeruje, że jeden z nich skarżył się na problem z prysznicem, który został właśnie rozwiązany przez drugiego.
#
# Tłumaczenie końcowe:
# [Wreszcie udało mi się skończyć naprawiać prysznic, więc teraz już nie masz powodu do narzekania!]
# ======================
# Naprawiłem samochód, czy udało ci się naprawić rower?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "fixed" (naprawiłem)
#    - "car" (samochód)
#    - "did you manage" (udało ci się)
#    - "fix" (naprawić)
#    - "your bike" (twój rower)
#
# 2. Ustalenie kontekstu:
#    - Mężczyzna pyta kobietę o jej samodzielne umiejętności naprawcze.
#    - Pytanie dotyczy dwóch różnych przedmiotów: samochodu i roweru.
#
# 3. Tłumaczenie dosłowne:
#    - "Naprawiłem samochód, czy udało ci się naprawić twój rower?"
#
# 4. Dostosowanie do naturalnego brzmienia języka polskiego:
#    - "Naprawiłem samochód, a ty dałaś radę naprawić swój rower?"
#
# Ostateczne tłumaczenie:
# [Naprawiłem samochód, a ty dałaś radę naprawić swój rower?]
# ======================
# Skończyłem raport, czy ukończyłaś prezentację?
# Rozumowanie krok po kroku:
#
# 1. Analiza struktury zdania:
#    - "I finished" - czas przeszły od czasownika "to finish" (skończyć)
#    - "the report" - rzeczownik w dopełniaczu liczby pojedynczej
#    - "did you complete" - pytanie o czynność wykonaną przez drugą osobę
#    - "the presentation" - rzeczownik w dopełniaczu liczby pojedynczej
#
# 2. Tłumaczenie poszczególnych elementów:
#    - "I finished" = "Skończyłem"
#    - "the report" = "raport"
#    - "did you complete" = "Czy ty skończyłaś"
#    - "the presentation" = "prezentację"
#
# 3. Uwzględnienie kontekstu dialogowego i relacji między rozmówcami:
#    - Mężczyzna pyta kobietę, co sugeruje nieformalny ton
#    - Pytanie dotyczy wspólnego projektu lub pracy
#
# 4. Łączenie elementów w spójne zdanie:
#    - "Skończyłem raport, czy ty skończyłaś prezentację?"
#
# 5. Ostateczne tłumaczenie:
#    [Skończyłem raport, czy ty skończyłaś prezentację?]
# ======================
# Siedziałam całą noc przygotowując prezentację, bo obiecałeś, że mi pomożesz — dlaczego się nie pojawiłeś?
# Rozumowanie krok po kroku:
#
# 1. "I stayed up all night" - Ta fraza oznacza, że osoba nie spała przez całą noc.
# 2. "preparing the presentation" - To wskazuje, że powodem braku snu było przygotowywanie prezentacji.
# 3. "because you promised to help me" - Osoba odnosi się do obietnicy pomocy ze strony drugiej osoby.
# 4. "why didn't you show up?" - Pytanie wyraża frustrację i rozczarowanie faktem, że druga osoba nie pojawiła się.
#
# Biorąc pod uwagę kontekst dialogu między kobietą a mężczyzną oraz dosłowne tłumaczenie poszczególnych elementów, otrzymujemy następujące tłumaczenie:
#
# [Nie spałam całą noc, przygotowując prezentację, bo obiecałeś mi pomóc, dlaczego więc nie przyszedłeś?]
# ======================
# Napisałam list, czy go wysłałeś?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "I" - ja
#    - "wrote" - napisałam
#    - "the letter" - list
#    - "did you send" - czy wysłałeś
#    - "it?" - (pytanie)
#
# 2. Kontekst dialogowy:
#    - Kobieta pyta mężczyznę
#    - Pytanie dotyczy czegoś, co ona zrobiła i chce się upewnić, że on wykonał swoją część zadania
#
# 3. Tłumaczenie dosłowne:
#    - Ja napisałam list, czy ty go wysłałeś?
#
# 4. Uwzględnienie kontekstu i stylu:
#    - W języku polskim pytania często zaczynają się od czasownika
#    - Warto dodać formę grzecznościową "pan" lub "proszę pana", aby lepiej oddać relację między osobami
#
# 5. Ostateczna wersja tłumaczenia:
#    [Czy pan wysłał ten list, który napisałam?]
# ======================
# Spędziłem cały dzień naprawiając twój laptop, a ty nawet nie powiedziałeś "dziękuję"!
# Rozumowanie krok po kroku:
#
# 1. "I spent the whole day" - Ta fraza oznacza, że dana osoba spędziła cały dzień robiąc coś.
# 2. "fixing your laptop" - To wyjaśnia, czym dokładnie zajmowała się ta osoba przez cały dzień - naprawianiem cudzego laptopa.
# 3. "and you didn't even say thank you!" - Ta część zdania wyraża frustrację i niezadowolenie z powodu braku podziękowania za wysiłek.
#
# Biorąc pod uwagę kontekst (mężczyzna do mężczyzny) oraz dosłowne tłumaczenie, możemy przełożyć to zdanie na język polski następująco:
#
# [Spojler:]
#
# "Poświęciłem cały dzień na naprawianie twojego laptopa, a ty nawet nie powiedziałeś dziękuję!"
#
# To tłumaczenie oddaje sens oryginalnego zdania, zachowując jego emocjonalny wydźwięk i odnosząc się bezpośrednio do sytuacji naprawy laptopa.
# ======================
# Czekałem na ciebie prawie godzinę w deszczu, a ty tylko napisałeś „sorry”?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "waited": czekałem
#    - "for you": na ciebie
#    - "almost an hour": prawie godzinę
#    - "in the rain": w deszczu
#    - "texted": wysłałeś SMS-a
#    - "sorry": sorry (przepraszam)
#
# 2. Uwzględnienie kontekstu dialogowego i relacji między mężczyznami:
#    - Mężczyzna mówi do mężczyzny
#    - Wyraża frustrację i rozczarowanie
#
# 3. Tłumaczenie dosłowne:
#    Czekałem na ciebie prawie godzinę w deszczu, a ty właśnie wysłałeś "przepraszam"?
#
# 4. Dostosowanie do naturalnego brzmienia języka polskiego:
#    Czekałem na ciebie prawie godzinę w deszczu, a ty teraz piszesz "przepraszam"?
#
# Ostateczna wersja tłumaczenia:
# [Czekałem na ciebie prawie godzinę w deszczu, a ty teraz piszesz "przepraszam"?]
# ======================
# Czekałam na ciebie prawie godzinę w deszczu, a ty tylko napisałaś „sorry”?
# Rozumowanie krok po kroku:
#
# 1. Analiza struktury zdania:
#    - Zdanie składa się z dwóch części:
#      a) "I waited for you for almost an hour in the rain"
#      b) "and you just texted 'sorry'"
#
# 2. Tłumaczenie pierwszej części:
#    - "I waited for you for almost an hour in the rain"
#    - Tłumaczenie: "Czekałam na ciebie prawie godzinę w deszczu"
#
# 3. Tłumaczenie drugiej części:
#    - "and you just texted 'sorry'"
#    - Tłumaczenie: "i ty tylko napisałaś 'przepraszam'"
#
# 4. Połączenie obu części:
#    - Oryginalne zdanie: "I waited for you for almost an hour in the rain, and you just texted 'sorry'?"
#    - Tłumaczenie: "Czekałam na ciebie prawie godzinę w deszczu, i ty tylko napisałaś 'przepraszam'?"
#
# 5. Uwzględnienie kontekstu (dialog między kobietami):
#    - Dodanie znaku zapytania na końcu zdania sugeruje, że jest to retoryczne pytanie lub wyrażenie emocji.
#
# Ostateczna wersja tłumaczenia:
# [Czekałam na ciebie prawie godzinę w deszczu, i ty tylko napisałaś 'przepraszam'?]
# ======================
# Posprzątałam kuchnię, wyniosłaś chociaż śmieci?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "cleaned" (sprzątnąłem/sprzątnęłam)
#    - "kitchen" (kuchnia)
#    - "did you" (czy ty)
#    - "take out" (wyjąć)
#    - "trash" (śmieci)
#
# 2. Ustalenie kontekstu:
#    - Kobieta mówi do kobiety
#    - Dialog między dwiema kobietami
#
# 3. Tłumaczenie poszczególnych elementów:
#    - "I cleaned the kitchen" = Sprzątnęłam kuchnię
#    - "did you at least take out the trash?" = czy chociaż wyjęłaś śmieci?
#
# 4. Łączenie elementów w logiczną całość:
#    - Sprzątnęłam kuchnię, czy chociaż wyjęłaś śmieci?
#
# 5. Dostosowanie do kontekstu:
#    - Wypowiedź sugeruje lekkie zirytowanie lub niezadowolenie ze strony mówiącej, ponieważ ona sprzątnęła kuchnię, ale oczekiwała, że druga osoba zajmie się śmieciami.
#
# 6. Ostateczne tłumaczenie:
#    [Sprzątnęłam kuchnię, czy chociaż wyjęłaś śmieci?]
# ======================
# Napisałam list, czy go wysłałaś?
# Rozumowanie krok po kroku:
#
# 1. Analiza struktury zdania:
#    - "I wrote the letter" - czas przeszły, pierwsza osoba liczby pojedynczej (ja)
#    - "did you send it?" - pytanie o czynność wykonaną przez drugą osobę (ty)
#
# 2. Kontekst dialogowy:
#    - Kobieta mówi do kobiety
#    - Pytanie dotyczy listu, który został napisany przez pierwszą kobietę
#
# 3. Tłumaczenie dosłowne:
#    - "I wrote the letter" -> "Napisałam list"
#    - "did you send it?" -> "Czy ty go wysłałaś?"
#
# 4. Łączenie elementów w jedno zdanie:
#    - "Napisałam list, czy ty go wysłałaś?"
#
# 5. Ostateczna wersja tłumaczenia:
#    [Napisałam list, czy ty go wysłałaś?]
# ======================
# Naprawiłem samochód, czy udało ci się naprawić rower?
# Rozumowanie krok po kroku:
#
# 1. Analiza słów kluczowych:
#    - "fixed" (naprawiłem)
#    - "car" (samochód)
#    - "did you manage" (udało ci się)
#    - "fix" (naprawić)
#    - "your bike" (twój rower)
#
# 2. Kontekst dialogowy i płeć mówiącego:
#    - Mężczyzna mówi do innego mężczyzny
#    - Pytanie o naprawę pojazdu
#
# 3. Tłumaczenie dosłowne:
#    - "Naprawiłem samochód, czy udało ci się naprawić twój rower?"
#
# 4. Dostosowanie do naturalnego języka polskiego:
#    - "Naprawiłem samochód, a ty dałeś radę naprawić swój rower?"
#
# Ostateczne tłumaczenie: [Naprawiłem samochód, a ty dałeś radę naprawić swój rower?]
# ======================
# Siedziałam całą noc pomagając ci z projektem, a teraz nawet tego nie pamiętasz?
# Rozumowanie krok po kroku:
#
# 1. "I stayed up all night" - Ta fraza oznacza, że dana osoba nie spała przez całą noc.
# 2. "helping you with your project" - To wyjaśnia powód, dla którego ta osoba nie spała - pomagała komuś innemu z projektem.
# 3. "and now you don't even remember it?" - To pytanie retoryczne, które wyraża rozczarowanie i zdziwienie faktem, że druga osoba nie pamięta tej pomocy.
# 4. Kontekst dialogu między kobietą a mężczyzną sugeruje, że kobieta może być lekko zirytowana lub zawiedziona brakiem uznania ze strony mężczyzny.
#
# Tłumaczenie końcowe:
# [Nie spałam całą noc, pomagając ci z twoim projektem, a teraz nawet tego nie pamiętasz?]
#
# To tłumaczenie oddaje dosłowne znaczenie oryginalnego zdania, jednocześnie uwzględniając emocjonalny ton wypowiedzi oraz kontekst dialogu między kobietą a mężczyzną.
# ======================
# Myślałam, że umówiliśmy się na wspólne sprzątanie, więc czemu wszystko robię sama?
# Rozumowanie krok po kroku:
#
# 1. Analiza struktury zdania:
#    - "I thought" - myślałam/myślałem
#    - "we agreed" - że się zgodziliśmy
#    - "to clean the house" - żeby posprzątać dom
#    - "together today" - razem dzisiaj
#    - "so why" - więc dlaczego
#    - "am I doing everything" - robię wszystko
#    - "alone" - sama
#
# 2. Kontekst dialogu między dwiema kobietami:
#    - Użycie formy grzecznościowej może być odpowiednie
#    - Możliwe użycie tonu lekko zirytowanego lub zawiedzionego
#
# 3. Tłumaczenie dosłowne:
#    - "Myślałam, że się zgodziliśmy posprzątać dom razem dzisiaj, więc dlaczego robię wszystko sama?"
#
# 4. Ostateczna wersja tłumaczenia:
#    [Myślałam, że umówiłyśmy się na sprzątanie domu razem dzisiaj, więc dlaczego ja robię wszystko sama?]
#
# To tłumaczenie oddaje sens oryginalnego zdania, uwzględniając kontekst dialogu między dwiema kobietami i potencjalny ton emocjonalny wypowiedzi.
# ======================
